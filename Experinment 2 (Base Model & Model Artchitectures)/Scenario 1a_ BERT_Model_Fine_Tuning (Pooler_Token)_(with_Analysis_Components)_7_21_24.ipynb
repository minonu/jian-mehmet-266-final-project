# %%
# %%capture
# !pip install tensorflow-datasets==4.8 --quiet
# !pip install tensorflow==2.15.0 --quiet #15 13
# !pip install tf_keras==2.15.0 --quiet
# !pip install tensorflow-text==2.15.0 --quiet #15
# !pip install pydot --quiet
# !pip install transformers==4.17 --quiet
# !pip install -U scikit-learn

# %%
#Tensorflow libiries
from tensorflow import keras
from tensorflow.keras.layers import Embedding, Input, Dense, Lambda
from tensorflow.keras.models import Model
import tensorflow as tf
import tensorflow.keras.backend as K
import tensorflow_datasets as tfds

#Transformers - BERT from huggingface
from transformers import BertTokenizer, TFBertModel
from transformers import logging
logging.set_verbosity_error()
from transformers import AutoConfig
from tensorflow.keras.callbacks import EarlyStopping

#NLP libiries
import sklearn as sk
from sklearn.metrics import classification_report
import os
import nltk
from nltk.data import find

#data process
import re
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import multiprocessing
import pandas as pd
import math
from bs4 import BeautifulSoup
import os
import json

# %%
#loading the pre-trained tokenizer and model
bert_tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
bert_model = TFBertModel.from_pretrained('bert-base-uncased')
# Out:
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/511M [00:00<?, ?B/s]

# %%
#load the dataset with error handling
try:
    train_df = pd.read_csv('full_train_data(Revised).csv')
except pd.errors.ParserError as e:
    print(f"Error reading CSV: {e}")
    # Print the lines around the problematic row
    with open('full_train_data(Revised).csv', 'r') as f:
        lines = f.readlines()
        for i in range(17622, 17626):
            if i < len(lines):
                print(lines[i])

test_df = pd.read_csv('full_test_data(Revised).csv')

# Adjust pandas display settings to show all rows and columns
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_colwidth', None)  # Show full content of each column
pd.set_option('display.width', None)  # Auto-detect width of the display

# %%
train_df.head(1)
# Out:
#                                                                    title        date  \
# 0  carly fiorina squanders momentum, slip republican debate?s main stage  2016-01-13
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      content_original  \
# 0  carly fiorina remains beloved eye many gop voter squandered momentum earned shining debate performance last summer, limp new year hoping lastminute miracle presidential primary. after clawed way onto main stage debate september, sole woman republican field relegated second tier thursday’s debate south carolina. the fiorina camp downplaying snub, insisting there’s still time sway huge swath primary voter say haven’t firmly committed candidate. poll don’t decide elections, neither medium executives. voter do,” anna epstein, campaign spokesperson, said. voter frustrated political class failed year year. carly win job, carly job.” but voter beginning question viability failed capitalize early good fortune. during appearance week cbs radio boston, supporter called ask mrs. fiorina polling posed question candidate want hear: would willing accept running mate rivals? i running president,” mrs. fiorina responded blunt fashion. leader.” the interaction came shortly fox business network announced monday mrs. fiorina sen. rand paul kentucky missed cut 9 p.m. primetime debate north charleston. instead, duo invited participate 6 p.m. undercard debate former pennsylvania sen. rick santorum former arkansas gov. mike huckabee, past two winner iowa caucuses. mr. paul plan skip event protest, mrs. fiorina. charlie gerow, adviser mrs. fiorina, said earlier forum provide another opportunity shine. carly fiorina always exceptionally well debate stage, proven beyond shadow doubt kind candidate is, thursday night give yet another opportunity visibly demonstrate credential capability commander chief,” mr. gerow said. donald trump, meanwhile, poised take center stage primetime forum, sandwiched sens. ted cruz texas marco rubio florida. flanking trio retired neurosurgeon ben carson former florida gov. jeb bush one side new jersey gov. chris christie ohio gov. john kasich other. mrs. fiorina’s slide come despite tallying 100 day campaigning iowa new hampshire — competitor — according tally democracy action. some blame struggle early decision outsource good chunk traditional campaign operation supportive super political action committee, leaving mrs. fiorina without campaign infrastructure capitalize relentless campaigning. also sense outsider” message grown stale. still, others baffled. i’ve seen her, fantastic,” said brian murphy, chairman rockingham county gop new hampshire. think offer lot substance short stump speech. can’t understand people interested topthree choice.” fergus cullen, former new hampshire gop chairman, said mrs. fiorina struggled get voter commit — much like others field. it bit mystery,” mr. cullen said mrs. fiorina’s standing race. sure get candidate time get candid, express frustration: ‘what to convert someone considering committed supporter?’” mrs. fiorina’s high point race far came wake memorable backtoback debate performance cleveland california, cast hillary clinton’s kryptonite. said outsider business acumen worldly knowledge needed political class” could not: bolster economy nation’s image world stage. mrs. fiorina also something done: got better exchange donald trump comment made looks. but added attention came increased scrutiny political past republican party official failed 2010 senate candidate california. critic also attacked professional record ceo hewlettpackard. since then, faded polls, realclearpolitics.com average poll show running ninth iowa eighth new hampshire. maybe would gotten constituency going donald trump wasn’t there,” said rogers, chairman polk county gop iowa. one hand, talk ceo, donald trump make claim well. maybe strength overshadowed candidates.” sign daily newsletter copyright © 2019 washington times, llc. click reprint permission.
#
#    bias bias_text            source
# 0     2     right  Washington Times

# %%
print(f"basic train_df info: ",train_df.shape)
# Out:
# basic train_df info:  (20114, 6)

# %%
test_df.head(1)
# Out:
#                                                             title        date  \
# 0  president obamas supreme court shortlist leaked. 6 contenders.  2016-03-12
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0  almost month passing supreme court justice antonin scalia, president obamas shortlist potential nominee replace appears taking shape. looking list washington post, new york times, associated press, nprs nina totenberg, six candidate keep appearing: merrick garland, u court appeal dc circuit ketanji brown jackson, u district court dc jane kelly, u court appeal eighth circuit patricia millett, u court appeal dc circuit sri srinivasan, u court appeal dc circuit paul watford, u court appeal ninth circuit reuters reported list even smaller: garland, srinivasan, watford. option previously floated — like attorney general loretta lynch, u sen. amy klobuchar, adalberto jordan court appeal eleventh circuit — either taken contention confirmed theyre considered. here need know final list — strengths, flaws, obama would would want pick — subjective order much buzz theyre picking up. sure also read ian millhiser thinkprogress, useful detail six. sri srinivasan — u court appeal dc circuit srinivasan far mostmentioned supreme court contender dc, owing largely unanimous 2013 confirmation dc court. thats extremely impressive: dc court far prominent circuit court, owing jurisdiction challenge rule made federal regulator like environmental protection agency. fact srinivasan could get unanimously approved court truly remarkable. his background help explain acrosstheboard enthusiasm. worked solicitor general office seven years: five george w. bush, two obama. clerked two republican judges, sandra day o’connor fourth circuit j. harvie wilkinson iii. most notably, he represented number corporate client private practice, including former enron executive jeffrey skilling supreme court appeal, newspaper fired reporter union activities, exxon trying escape liability murder torture security force committed indonesia. anything, many liberal activist might think srinivasan conservative promote highest court. then again, would make history first asianamerican south asian justice, first hindu justice. moreover, liberal decision belt already. reinstated department labor rule extending minimum wage overtime protection home care worker lower court judge blocked it, declined halt obamas climate change rule (the supreme court later halted itself). however, latter case might reason obama nominate him. dc circuit ruled whether halt rules, hasnt ruled legal challenge yet, srinivasan panel set consider that. nominating srinivasan present risk president could lead different judge swapped hear case, millhiser explains. srinivasan confirmed supreme court, would also need recuse case already ruled request temporarily halt plan circuit judge. that hasnt enough stop srinivasan considered, though. obama reportedly asked fbi conduct background check him, ap report (and reuters confirms) he one three favorite position, alongside watford garland. paul watford — u court appeal ninth circuit at first glance, watford immensely appealing, qualified nominee. he 48, would third african american appointed court. also went ucla law school, might provide valuable form diversity time eight nine justice went yale harvard (and ginsburg graduated columbia transferring … harvard). clerked widely liked (albeit idiosyncratic) conservative judge alex kozinski, well ginsburg. conservative law scholar eugene volokh enthusiastic supporter watfords appellate confirmation. whats more, account good judge. three year court, earned reputation smart careful jurist, totenberg writes. indeed, two opinion — one dissent one majority opinion — ultimately vindicated supreme court last term. those two case los angeles v. patel, watford ruled (and supreme court affirmed) city code provision letting police officer look hotel guest record without warrant violated fourth amendment; reed v. town gilbert, wherein circuit court ruled favor town sign regulation set different rule size political ideological sign opposed one providing directions, watford dissented supreme court followed reasoning striking regulation  ...
#
#    bias bias_text source
# 0     0      left    Vox

# %%
print(f"basic test_df info: ",test_df.shape)
# Out:
# basic test_df info:  (5029, 6)

# %%
# extract the train and test text from both dataframes
train_text = train_df['content_original']
train_text_labels = train_df['bias']

validate_text = test_df['content_original'][0:2000]
validate_text_labels = test_df['bias'][0:2000]

test_text = test_df['content_original'][2000:]
test_text_labels = test_df['bias'][2000:]


print(f"size of training dataset: ",len(train_text))
print()
print(f"size of valid dataset: ",len(validate_text))
print()
print(f"size of testing dataset: ",len(test_text))
print()
print(f"Left with Label 0 ")
print(f"Center with Label 1 ")
print(f"Right with Label 2 ")
# Out:
# size of training dataset:  20114
#
# size of valid dataset:  2000
#
# size of testing dataset:  3029
#
# Left with Label 0
# Center with Label 1
# Right with Label 2

# %%
MAX_SEQUENCE_LENGTH = 512

# %%
# tokenize the dataset, truncate at `max_length`,

#tokenizing the train text
x_train = bert_tokenizer(train_text.tolist(),
              max_length=MAX_SEQUENCE_LENGTH,
              truncation=True,
              padding='max_length',
              return_tensors='tf')
y_train = train_text_labels

#tokenizing the validate text
x_validate = bert_tokenizer(validate_text.tolist(),
              max_length=MAX_SEQUENCE_LENGTH,
              truncation=True,
              padding='max_length',
              return_tensors='tf')
y_validate = validate_text_labels


#tokenizing the test text
x_test = bert_tokenizer(test_text.tolist(),
              max_length=MAX_SEQUENCE_LENGTH,
              truncation=True,
              padding='max_length',
              return_tensors='tf')
y_test = test_text_labels

# %%
#BERT base uncased model configurations
config = AutoConfig.from_pretrained('bert-base-uncased')

config
# Out:
# BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.17.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }

# %% [markdown]
# #BERT Uncase Model Fine-Tuning

# %%
def create_bert_classification_model(bert_model,
                                     num_train_layers=0,
                                     num_classes = 3,
                                     hidden_size = 768,
                                     dropout=0.3,
                                     attention_probs_dropout_prob = 0.2,
                                     hidden_dropout_prob=0.25,
                                     learning_rate=0.00005):
    """
    Build a simple classification model with BERT. Use the Pooler Output for classification purposes
    """
    if num_train_layers == 0:
        # Freeze all layers of pre-trained BERT model
        bert_model.trainable = False

    elif num_train_layers == 12:
        # Train all layers of the BERT model
        bert_model.trainable = True

    else:
        # Restrict training to the num_train_layers outer transformer layers
        retrain_layers = []

        for retrain_layer_number in range(num_train_layers):

            layer_code = '_' + str(11 - retrain_layer_number)
            retrain_layers.append(layer_code)


        print('retrain layers: ', retrain_layers)

        for w in bert_model.weights:
            if not any([x in w.name for x in retrain_layers]):
                #print('freezing: ', w)
                w._trainable = False

    input_ids = tf.keras.layers.Input(shape=(MAX_SEQUENCE_LENGTH,), dtype=tf.int64, name='input_ids_layer')
    token_type_ids = tf.keras.layers.Input(shape=(MAX_SEQUENCE_LENGTH,), dtype=tf.int64, name='token_type_ids_layer')
    attention_mask = tf.keras.layers.Input(shape=(MAX_SEQUENCE_LENGTH,), dtype=tf.int64, name='attention_mask_layer')

    bert_inputs = {'input_ids': input_ids,
                   'token_type_ids': token_type_ids,
                   'attention_mask': attention_mask}

    bert_out = bert_model(bert_inputs)

    pooler_token = bert_out[1]
    #cls_token = bert_out[0][:, 0, :]

    # hidden_1 = tf.keras.layers.Dense(hidden_size, activation='relu', name='hidden_layer_1')(pooler_token)
    # hidden_1 = tf.keras.layers.Dropout(dropout)(hidden_1)


    classification = tf.keras.layers.Dense(num_classes, activation='softmax',name='classification_layer')(pooler_token)

    classification_model = tf.keras.Model(inputs=[input_ids, token_type_ids, attention_mask], outputs=[classification])

    classification_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                                 loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
                                 metrics='accuracy')

    return classification_model

# %%
#let's get a fresh instance of the bert_model -- good practice
bert_model = TFBertModel.from_pretrained('bert-base-uncased')
bert_classification_model = create_bert_classification_model(bert_model, num_train_layers=12)

# %%
#confirm all layers are frozen
bert_classification_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  attention_mask_layer (Inpu  [(None, 512)]                0         []
#  tLayer)
#
#  input_ids_layer (InputLaye  [(None, 512)]                0         []
#  r)
#
#  token_type_ids_layer (Inpu  [(None, 512)]                0         []
#  tLayer)
#
#  tf_bert_model_1 (TFBertMod  TFBaseModelOutputWithPooli   1094822   ['attention_mask_layer[0][0]',
#  el)                         ngAndCrossAttentions(last_   40         'input_ids_layer[0][0]',
#                              hidden_state=(None, 512, 7              'token_type_ids_layer[0][0]']
#                              68),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  classification_layer (Dens  (None, 3)                    2307      ['tf_bert_model_1[0][1]']
#  e)
#
# ==================================================================================================
# Total params: 109484547 (417.65 MB)
# Trainable params: 109484547 (417.65 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(bert_classification_model, show_shapes=True, dpi=90)

# %%
from tensorflow.keras.callbacks import EarlyStopping
# Early stopping callback to avoid overfitting issue
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=1,
    mode='max',
    restore_best_weights=True  # Restore model weights from the epoch with the best value of the monitored quantity
)

# %%
bert_classification_model_history = bert_classification_model.fit(
    [x_train.input_ids, x_train.token_type_ids, x_train.attention_mask],
    y_train,
    validation_data=([x_validate.input_ids, x_validate.token_type_ids, x_validate.attention_mask], y_validate),
    batch_size=32,
    epochs=4,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/4
# 629/629 [==============================] - 568s 838ms/step - loss: 0.6440 - accuracy: 0.6972 - val_loss: 0.3651 - val_accuracy: 0.8595
# Epoch 2/4
# 629/629 [==============================] - 523s 832ms/step - loss: 0.3051 - accuracy: 0.8894 - val_loss: 0.2825 - val_accuracy: 0.8890
# Epoch 3/4
# 629/629 [==============================] - 523s 832ms/step - loss: 0.2003 - accuracy: 0.9316 - val_loss: 0.3667 - val_accuracy: 0.8705

# %%
history = bert_classification_model_history.history

# Plotting accuracy
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history['accuracy'], label='Training Accuracy')
plt.plot(history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plotting loss
plt.subplot(1,2,2)
plt.plot(history['loss'], label='Training Loss')
plt.plot(history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
#Fine-Tuned BERT model overall prediction score
score = bert_classification_model.evaluate([x_test.input_ids, x_test.token_type_ids, x_test.attention_mask],
                                                  y_test)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 95/95 [==============================] - 25s 265ms/step - loss: 0.2733 - accuracy: 0.8983
# Test loss: 0.27327874302864075
# Test accuracy: 0.8983162641525269

# %%
predictions_model= bert_classification_model.predict([x_test.input_ids, x_test.token_type_ids, x_test.attention_mask])
predictions_model = tf.argmax(predictions_model, axis=-1)
predictions_model
# Out:
# 95/95 [==============================] - 28s 261ms/step
# <tf.Tensor: shape=(3029,), dtype=int64, numpy=array([1, 1, 2, ..., 2, 2, 0])>

# %%
print(classification_report(y_test, predictions_model.numpy(),
                            target_names=['Left ','Center','Right']))
# Out:
#               precision    recall  f1-score   support
#
#        Left        0.92      0.89      0.91      1263
#       Center       0.87      0.90      0.88       688
#        Right       0.89      0.91      0.90      1078
#
#     accuracy                           0.90      3029
#    macro avg       0.89      0.90      0.90      3029
# weighted avg       0.90      0.90      0.90      3029

# %%
def plot_confusion_matrix(y_true, y_pred, label_names):
    cm = tf.math.confusion_matrix(y_true, y_pred)
    cm = cm/cm.numpy().sum(axis=1)[:, tf.newaxis]

    plt.figure(figsize=(20,7))
    sns.heatmap(
        cm, annot=True,
        xticklabels=label_names,
        yticklabels=label_names)
    plt.xlabel("Predicted")
    plt.ylabel("True")

# %%
target_names=['Left ','Center','Right']
plot_confusion_matrix(y_test, predictions_model.numpy(), target_names)

# %%
bert_wrong_guesses = np.where(y_test != predictions_model.numpy())

# %%
print(f'Number of Wrong Guesses: ',len(bert_wrong_guesses[0]))
# Out:
# Number of Wrong Guesses:  308

# %%
#sampling 20 of the wrong precditions
wrong_guesses = [i for i in np.squeeze(bert_wrong_guesses[0])]
decoded_wrong_guesses_text=[]

for i in wrong_guesses[:]:
  decoded_text = bert_tokenizer.decode(x_test['input_ids'][i], skip_special_tokens=True)

  # print("Input text:")
  # print(decoded_text)
  decoded_wrong_guesses_text.append(decoded_text)
  # print("True label:")
  # print(y_test.iloc[i])
  # print("Predicted label:")
  # print(predictions_model.numpy()[i])

  # print("-" * 50)

# %%
len(decoded_wrong_guesses_text)
# Out:
# 308

# %%
sources_analysis = test_df.loc[wrong_guesses]

# %%
sources_analysis['source']
# Count the occurrences of each source
source_counts = sources_analysis['source'].value_counts()

# Create a bar plot
plt.figure(figsize=(12, 6))
source_counts.plot(kind='bar')

# Customize the plot
plt.title('Distribution of Wrong Guess''Sources')
plt.xlabel('Source')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Convert 'date' to datetime if it's not already
sources_analysis['date'] = pd.to_datetime(sources_analysis['date'])

# Extract year from the date
sources_analysis['year'] = sources_analysis['date'].dt.year

# Count occurrences of each year
year_counts = sources_analysis['year'].value_counts().sort_index()

# Create a bar plot
plt.figure(figsize=(12, 6))
year_counts.plot(kind='bar')

# Customize the plot
plt.title('Distribution of Sources by Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=0)  # No rotation for years
plt.tight_layout()

# Show the plot
plt.show()

# %%
for i in wrong_guesses[:50]:
  decoded_text = bert_tokenizer.decode(x_test['input_ids'][i], skip_special_tokens=True)

  print("Input text:")
  print(decoded_text)
  print("True label:")
  print(y_test.iloc[i])
  print("Predicted label:")
  print(predictions_model.numpy()[i])

  print("-" * 50)
# Out:
# Input text:
# democrat congress seeking capitalize unrest teacher pay led classroom walkout handful states, offering electionyear plan roll back part last year ’ s gop tax cut boost fund schools, including higher wage educators. state local school district would get $ 50 billion decade raise teacher pay recruit educators. plan would provide another $ 50 billion school building resources, expand public school teachers ’ collective bargaining rights. the measure among series initiative democrat offering rally core voter ahead election november, every house seat ballot, along third senate seats. minority party chambers, democrat lack power bring plan vote. on monday, democrat focused controversy surrounding president donald trump allegation corruption administration, promising new ethic rule restriction campaign donation undisclosed contributors. to pay education plan, house minority leader nancy pelosi democratic leader want cancel new tax cut benefit wealthiest 1 percent americans. instead giving tax cut richest americans, give pay raise teacher country student depend succeed, ” senate majority leader chuck schumer said news conference. joining democrat leader american federation teacher national education association, key donor party candidates. the recent teacher walkout occurred important election battleground state including arizona, gop senator jeff flake retiring, west virginia, incumbent democratic senator joe manchin fighting keep seat. teacher west virginia ended nineday strike march 5 percent pay raise. state teacher demonstrated higher pay include oklahoma, kentucky colorado.
# True label:
# 1
# Predicted label:
# 0
# --------------------------------------------------
# Input text:
# with supreme court expected rule day whether state samesex marriage ban constitutional, hillary clinton become one country prominent politician favor marriage equality. every loving couple & family deserves recognized & treated equally law across nation. # lovemustwin # lovecantwait – h — hillary clinton ( @ hillaryclinton ) april 28, 2015 but clinton prominent support samesex marriage right part sharp shift issue past year — transformation has, many ways, mirrored american whole went time span. during 2008 campaign, clinton opposed federal samesex marriage rights, saying issue left states. take 2016 campaign, shes complete support. it pivot struggled explain, including june told nprs terry gross, think youre trying say that, know, used opposed, im favor, political reason — thats flat wrong. it easy imagine clinton, like politicians, made calculated political decision flipflop. political environment far friendlier lgbt right decade ago, all. clinton, who 67 year old, would similar million american age group changed mind nonpolitical reasons. support samesex marriage nearly tripled among american around clinton age 1996 2014, according gallup surveys. so even though clinton might find predicament — supporting policy — case samesex marriage, attitude changing belief mirror publics. there charitable version clinton evolution look lot like american public, come see issue differently genuinely evolved. i think american — lgbt — appreciate journey many folk taken issue marriage, jason rahlan, spokesperson human right campaign ( hrc ), also worked clinton state department 2008 campaign, told email. many seen within families. hillary clinton evolution match national trend even way clinton talk issue similar americans. clinton insists genuinely evolved stance — phrase president barack obama also used describe thought samesex marriage. clinton explained it, didnt grow thinking possibility samesex marriages, shifted position advocate pushed issue public spotlight forced give thought. just youre politician, doesnt mean youre thinking human being, clinton told nprs gross. gather information, think positions, youre 100 percent set … youre constantly reevaluating stand. true me. the final reevaluation came clinton officially announced support samesex marriage 2013. clinton relationship lgbt advocate always somewhat tense, least president bill clinton approved defense marriage act, effectively banned samesex marriage federal level supreme court struck part law 2013. but lgbt advocate quickly fell behind clinton announced support marriage equality. hrc president chad griffin wrote time, honored secretary clinton moving statement part american marriage equality series. left office speak publicly issue important us, hillary share experience secretary
# True label:
# 0
# Predicted label:
# 1
# --------------------------------------------------
# Input text:
# the americanordered drone strike killed one iran ’ s powerful military leaders, qassem soleimani, triggered retaliation iran put american troop middle east heightened alert. also brought foreign policy top news cycle. event unfold uncertain, leave analysis others expertise world affairs. instead, we ’ d like take step back use political science polling data explore question heightened tension iran could affect 2020 primary general elections. first, political science research found foreign policy doesn ’ t significantly affect people ’ s votes. isn ’ t always case. example, foreign policy impact it ’ s big part national conversation two party clearly contrasting position — two condition iran episode could meet. we don ’ t actually know much role international affair play primaries, though, it ’ s rare primary candidate experienced foreign policy. year, candidate former vice president joe biden. two recent poll say democratic primary voter trust foreign policy. according cnn, nearly half ( 48 percent ) democrat democratic leaner said thought biden could best handle foreign policy ; sen. bernie sander came second place 14 percent. poll taken immediately strike killed soleimani, huffpost / yougov found 62 percent democrat democratic leaner trust biden iran, although sander sen. elizabeth warren weren ’ t far behind, 47 percent trusting ( respondents allowed select multiple candidate trusted ). but even initial setup chessboard privilege biden, candidate move issue could also determinative. someone like sanders, critical biden ’ s vote go war iraq, could seize upper hand primary becomes question antiwar. voter likely listening closely candidate say iran next week ’ s debate, could makeorbreak moment many candidates, one theory foreign policy affect primary serf litmus test serious candidate must pass. take 2016 republican primaries, ben carson may flunked test when, coordinated terrorist attack paris november 2015, struggled articulate would combat terrorism. even adviser said publicly unprepared issue. although it ’ s impossible know exactly much hurt carson voters ’ eyes, running even nowpresident trump poll time attacks, sharply declined thereafter ceased serious threat nomination. extreme example aside, though, iran ’ s effect primary might fleeting. news cycle move on, past event touted game changers ” failed permanently change state race. remember polling bump biden ( or anyone else ) get week could wear quickly, especially conflict defuses. for iran real effect general election, would likely stay news next several months. even then, it ’ s clear effect might be. theory, might expect republican advantage election focused around national security : gop long seen better democrat protecting
# True label:
# 1
# Predicted label:
# 0
# --------------------------------------------------
# Input text:
# according gallup, average presidential honeymoon last seven months. window losing party declares partisan peace, allows incoming president pick cabinet launch agenda victory mandates. presidential honeymoon venerable american tradition one democracy ’ s pillars. generation ceremonial support peaceful transition power, peaceful resolution partisan conflicts. not election year. honeymoon. year even trump arrives oval office, opposition cry resist! block! reject! antiamerican radical like michael moore, indeed called 100 day resistance ” trump presidency, leadership democratic party vowed fight trump ’ s appointments, attacked election result expression popular racism, attempted discredit electoral college falsely calling legacy slavery, even accused trump russian agent, pawn chess game dictator vladimir putin. sad day america world ’ s oldest political party, whose name proclaims partisan democracy, come force saboteur system. nor simply fit democratic absentmindedness. instead, culmination long developing shift democratic party politics, shift symbolized current favorite become next leader. keith ellison muslim radical spent formative adult year vocal supporter antiamerican, antisemitic racist louis farrakhan. ellison reflects power bernie sander radical democratic party according recent gallup poll represent majority, even though lost rigged primary election would made party ’ s presidential nominee. the face new democratic party revealed seminal moment second clintontrump presidential debate. came trump turned camera said, hillary tremendous hatred heart. ” referring notorious statement half trump ’ s supporter belonged basket deplorables, ” followed iteration mind : racist, sexist, homophobic, xenophobic, islamophobic — you name it. unfortunately people like that. lifted up. ” what made moment pivotal slur idiosyncratic tic democratic standardbearer leader party ’ s moderate ” wing. logical expression identity politics become party ’ s creed. every political issue conflict reduced conflict races, gender ethnic origin inevitably lead demonization opposition racist, sexist … deplorable. mentality swallowed democratic party caused view politics art compromise war indecent irredeemable. succinct summary democrats ’ rejection traditional presidential honeymoon about. nonetheless, significant presidential debate trump ’ s readiness confront hillary face describe attack was : hate. kind indiscreet character description become signature reflex trump ’ s campaign. never one presidential candidate bluntly confronted another. never republican dared characterize democratic opponent damning moral term national audience. this attempt reverse election result, block trump ’ s appointment cripple agenda fail. republican faced extreme attack appointment would thrown many bus. trump target attack outset campaign. reason attacked readiness confront head called political correct
# True label:
# 2
# Predicted label:
# 0
# --------------------------------------------------
# Input text:
# it suggested there ’ s war ” fox news network completes critical personnel change launch new programming. certainly critic hope viewer impression fox suffering ratings. not, indisputable. network still rules. 22nd week row, fox news remains mostwatched cable network all, besting hgtv, usa tbs, say latest nielsen medium research findings. additionally, fox news program made 15 top 30 telecast basic cable. and matter might hear rating minutiae, fox news outranked msnbc cnn prime time, drawing 2. 2 million viewer compared msnbc ’ s 1. 3 million cnn ’ s 1. 1 million. fox also triumphed breaking news terrorist attack london terror emerged : fox news no. 1 cable news network saturday evening 2. 1 million viewers ; cnn garnered 1. 2 million msnbc telling 628, 000 viewers. ever thus, seems. brief, fox news no. 1 cable news channel 15 year according nielsen numbers. fox news still strong despite turmoil, ” say jeff mccall, depauw university communication professor, oped indianapolis star. controversy surrounding fox news channel recent months, one could conclude channel rating trouble. surprisingly, however, network ’ s prime time audience may 11 percent higher may 2016. mr. mccall continues, msnbc cnn seen even larger growth, gain come expense fox. msnbc, particular, expanded audience laserlike focus trump administration ’ s daily dramas. question msnbc whether antitrump fervor fueled rating gain staying power. ” say amen, somebody a slim majority american ( 55 percent ) say religion answer today ’ s problems. although percentage declined substantially time, relatively stable past year half alltime low 51 percent may 2015, ” report gallup analyst art swift. and inevitable partisan divide : 71 percent republicans, 50 percent independent 47 percent democrat also agree faith still answer. strongest sentiment — 85 percent — found among attend church weekly, lowest — 9 percent — religious preference. a slim majority american believe religion answer problems, vast majority think god played part process human creation, believe god also role content bible, ” say mr. swift, summarizing multiple gallup findings. religious fervor may declining, questions, american still assert religion topic relating religion relevance 21stcentury life. ” curiouser curiouser an event note wednesday nation ’ s capital : transportation secretary elaine chao offer keynote speech competitive enterprise institute ’ s annual dinner, staged sparkling hotel far white house. ms. chao likely address regulatory reform forwardthinking idea infrastructure yes, nation ’ s transportation. the event unique theme, however :
# True label:
# 2
# Predicted label:
# 1
# --------------------------------------------------
# Input text:
# the contentious contour democratic presidential primary came full view new hampshire weekend, month cordial campaigning iowa quickly escalated raucous sprint tuesday primary. vermont sen. bernie sander former south bend, indiana, mayor pete buttigieg, drawing largest crowd granite state neartie iowa caucuses, began treating primary rival democratic nomination. former vice president joe biden, meanwhile, unleashed harshest attack advertisement primary date, targeting buttigieg struggle regain footing prevent support among moderate democrat evaporating amid worsethanexpected finish iowa new threat centrist lane minnesota sen. amy klobuchar, whose event mostly outdrew bidens weekend. and massachusetts sen. elizabeth warren, fallen behind sander among party progressive voter buttigieg among collegeeducated liberals, sought avoid embarrassing finish neighboring state. across new hampshire, undecided voter weekend still using result iowa well friday night combative debate new hampshire decide throw support tuesday. ive leaning toward biden. havent really impressed joe debates, want see person, said valerie brown, 64yearold retired health care consultant derry, new hampshire, considering biden buttigieg. sometimes get caught language kind lose train thought. just, energy. seems little seems little old. brown expressing opinion held number voter cnn spoke weekend. i dont want basically obama 2. 0. want think himself, said seth mandell, 57yearold nashua deciding biden, buttigieg klobuchar. time changing.... want biden able say, ok, then, now, weve got do. the former vice president tumble reshaped race, higheststakes battle two men cnn poll conducted university new hampshire found leading ahead tuesday primary. sanders, favorite new hampshire, buttigieg, whose momentum iowa helped compete state neighboring senator, spent weekend sparring afar series television appearances, rally town halls. sander seized buttigiegs acceptance money wealthy donors, using separate competitor argue campaign, fueled online contributions, rewriting rule campaign finance. of course, matters, sander said buttigieg donation event plymouth. think person youre giving money going stand corporate elite fight government represents us? dont think so. buttigieg, course weekend, responded sander arguing democrat cant afford distance wealthy people want oust president donald trump. bernies pretty rich id happily accept contribution him, buttigieg said. making sure bring everybody fight moment going going donald trump. buttigieg chose go sander different way : ubiquitous call revolution. i respect sen. sanders, butt
# True label:
# 0
# Predicted label:
# 1
# --------------------------------------------------
# Input text:
# the supreme court announced monday hear california v. texas united state house representative v. texas, two consolidated case represent existential threat obamacare, brought coalition republicangoverned states. third time since president barack obama signed affordable care act 2010, justice hear lawsuit seeking eviscerate legislation. texas turn congress ’ s decision repeal obamacare ’ s individual mandate. originally enacted, affordable care act requires american either obtain health insurance pay higher taxes. tax law president donald trump signed 2017 reduces amount tax zero. because supreme court upheld fully functional mandate valid exercise congress ’ s power tax 2012, texas plaintiff argue zeroedout version mandate unconstitutional — something tax raise money whatsoever? also claim entire affordable care act must fall deactivated mandate unconstitutional. the republican legal argument obamacare case widely viewed ridiculous, even many lawyer scholar spent much last decade trying convince court repeal president obama ’ s signature achievement. jonathan adler, conservative law professor — leading evangelist earlier lawsuit seeking undercut affordable care act reading poorly drafted provision law cut much act ’ s funding — labeled many red states ’ argument implausible, ” hard justify, ” surprisingly weak. ” wall street journal ’ s editorial board labeled lawsuit texas obamacare blunder. ” yuval levin, prominent conservative policy wonk, wrote national review texas lawsuit doesn ’ t even merit called silly. it ’ s ridiculous. ” and yet, lawsuit received favorable treatment republican federal judges. judge reed o ’ connor, former republican senate staffer turned district judge, ordered whole affordable care act repealed entirety. two republican federal appeal court judge reached somewhat mild conclusion — striking small portion law sending case back o ’ connor reconsider provision fall. but, holding creates work judge o ’ connor, remains likely kill much law can. in addition weighing merit plaintiffs ’ arguments, supreme court need consider whether federal court jurisdiction hear case. general rule, one allowed challenge law federal court unless show injured law. zeroedout mandate nothing, it ’ s highly doubtful anyone allowed challenge it. assuming president trump get replace current justices, supreme court unlikely agree lowercourt judge ruled obamacare. chief justice john robert twice broke conservative colleague lawsuit attacking obamacare, robert especially likely reject texas plaintiffs ’ legal arguments. but, long lawsuit exists, remains threat obamacare. guarantee court ’ s membership change. how got point a noted above, affordable care act originally required american either carry insurance pay higher taxes. supreme court famously upheld provision, known individual mandate, ” valid exercise congress ’ power levy tax nfib v. sebelius ( 2012 ). congressional republican spent much
# True label:
# 0
# Predicted label:
# 2
# --------------------------------------------------
# Input text:
# china ’ s economy shrank 6. 8 % first three month 2020, country ’ s first contraction record stark sign financial impact coronavirus pandemic. the news came chinese authority revised death toll wuhan, hardesthit city virus first emerged, 50 %, 3, 869 2, 579. the economic contraction, reported china ’ s national bureau statistic friday, come month paralysis country went lockdown contain virus, emerged central hubei province december. infected 2 million people globally killed 140, 000. while much rest world grapple virus, china appears overcome worst it. friday, reported 26 new confirmed cases, lowest daily total two weeks. overall china reported 3, 000 death 80, 000 infection coronavirus. even chinese authority past month pushed restart economy, fear new infection forced part country enact new restrictions. china closed border almost foreigner arriving abroad limited international flights. play video 1 : 09 timelapse show busy wuhan street coronavirus lockdown lifted – video depressed demand overseas likely hit chinese economy further. china ’ s firstquarter contraction follows decline 2019, chinese economy expanded slowest pace almost 30 year – result slowing consumption, pullback debtfuelled growth protracted trade war us. analyst polled reuters estimate china ’ s yearly growth 2020 slow 2. 5 % 6. 1 % last year, weakest pace since last year cultural revolution. friday ’ s data showed industrial output fell 1. 1 % march, betterthan expected drop. retail sales, measure consumption, fell 15. 8 %, steeper predicted, fixed asset investment, gauge spending infrastructure projects, equipment property, fell 16 % line expectations. on friday, germany ’ s health minister said spread virus become controllable ” number infection sank new low, malaysia also reported lowest daily increase since march, 69 new cases. spain, daily death toll 585 friday, previous peak 900 day. denmark said would allow business open next week restriction lifted, u announced plan reopen u state phases. the french president, emmanuel macron, thursday described pandemic profound anthropological shock ”. told financial times : stopped half planet save lives, precedent history. change nature globalisation, lived past 40 years. ” other development coronavirus pandemic included :
# True label:
# 0
# Predicted label:
# 1
# --------------------------------------------------
# Input text:
# a iran talk intensify, boehner netanyahu warn deal a international envoy pressed forward nuclear talk iran sunday, new question arose issue observer thought already resolved : whether iran would ship much uranium stockpile country. meanwhile, house speaker john boehner declared tehran cannot trusted adhere deal, israeli prime minister benjamin netanyahu also escalated warning stillunfinished accord. with unofficial deadline tuesday looming come agreement, secretary state john kerry decided cancel plan appear monday tribute boston mentor, late sen. ted kennedy. joined swiss city lausanne emissary tehran five country — germany, china, russia, france britain — involved negotiations. by late sunday, however, appeared several sticking point remained, including one surprised many people following talks. iranian negotiator abbas araghchi said report iran agreed ship stockpile uranium outside border wrong. earlier indication iranian agreed send material russia, presumably putting fuel reach unavailable military purposes. none news published completely accurate, particular transfer uranium country, ” araghchi said, according semiofficial iranian students ’ news agency. program intend this. ” he insisted, however, way ease worry uranium would misused. new york time reported western official suggested material could diluted, example, it ’ s easily enriched use atomic weapon program. other point contention talk include handle sanction leveled iran, type research development centrifuge iranian allowed pursue coming year format preliminary deal would presented public. in another sign deal imminent, associated press reported russian foreign minister sergei lavrov would leave talk monday afternoon would return agreement reached. the u. s. domestic debate deal played airwave sunday, boehner repeating skepticism. islamic republic ’ s leader intention keeping word, ” republican said cnn, adding negotiation proof current sanction working. on abc, meanwhile, white house spokesman josh earnest said boehner think united state bomb iran keep nuclear weapon — feel way, courage conviction say so. ” earnest also reiterated white house looking extend negotiation beyond tuesday. at time, netanyahu, view iran mortal threat country, reportedly told cabinet sunday : deal, appears emerging, bear fears, even that. ” pointing iran ’ s backing houthi rebel advancing yemen, latest front spreading violence middle east, israeli leader warned : iranlausanneyemen axis dangerous humanity, must stopped. ” also expressed concern directly u. s. senate leader weekend. over weekend, side insisted time bend. ultimately, it ’ s time iranian send clear signal international community whether willing make serious commitment required, ” earnest said sunday. in negotiations, side must show flexibility,
# True label:
# 0
# Predicted label:
# 2
# --------------------------------------------------
# Input text:
# i struggle volume coverage that ’ s produced every time republican announces, even teases, primary challenge president trump. one hand, notable former illinois rep. joe walsh threw hat ring week, former trump supporter stature ( after leaving congress, became nationally syndicated radio host ). other, covering walsh ilk serious candidate implies trump actually vulnerable primary challenge, and, well … he ’ s not. there plenty reason primary challenge trump probably fall flat. starters, serious primary challenge fairly rare ; last sitting president denied renomination chester arthur 1884. ( yes, lyndon johnson, retired could properly lose nomination — although primary challenger probably something decision. ) putting aside, however, biggest thing trump going extremely popular among republican — that ’ s true virtually every poll. example, 88 percent gop approves job performance latest gallup poll. ( true, trump approval isn ’ t quite high among voter merely lean republican, even poll incorporate leaner still give overwhelming intraparty support — 82 percent one recent poll. ) according cnn analysis december, president last 70 year beloved among member party ( as measured new hampshire primary ) dwight eisenhower 1956. important president faced muscular primary challenge modern primary era 75 percent approval member party : gerald ford 1976, jimmy carter 1980 george h. w. bush 1992. yes, three went lose general election. say primary challenge caused losses ; could weak incumbent draw primary challengers. trump currently weak among member party ( although unpopular overall ), it ’ s unclear primary challenge foreshadow result. finally, headtohead poll republican primary give trump massive lead primary challengers. lead former massachusetts gov. bill weld, first notable candidate jump race, anywhere 60 85 points, even lead highprofile hypothetical challenger like utah sen. mitt romney former ambassador united nation nikki haley 80 points. but stubborn fact don ’ t appear deterring challenger — though it ’ s probably coincidence might run former politician current office lose. addition walsh weld, former south carolina rep. mark sanford considering jumping in. beating trump may real goal ( sanford, example, acknowledged would close impossible ) ; instead, may simply hoping spur conversation party ’ s direction. earlier year, colleague geoffrey skelley devised scale rating success ” presidential primary challenger front, 1 ( noname candidates ) 5 — ( asyet hypothetical ) candidate manages successfully topple sitting president. right now, would think walsh, weld potentially sanford somewhere level 1 2. known commodity could put together professional campaign apparatus, seems unlikely attract much support pat buchanan bush 1992, model level 2 primary challenge. but
# True label:
# 1
# Predicted label:
# 0
# --------------------------------------------------
# Input text:
# analysis / opinion : with another week, another example immigration system harming american workers. case, it ’ s h1b visa program, grant 85, 000 visa year, ostensibly help u. s. company fill hightech position which, purportedly, american suitably educated. jobs, company like microsoft facebook argue, require specialization computer science rely importation superhero geniuses. something. well, fast. american worker finding they ’ re losing job h1b visa holders, often not, fired worker also endure ignominy training replacements. this, course, opposite we ’ re told time importance h1b visa scheme. need attract best brightest ” around world help u compete, microsoft general counsel told national public radio ( npr ) 2013. considering fact record 92 million american workforce, one would think employing best brightest ” might better place start, let alone importing worker condemning even american unending joblessness. the latest case unfortunate, growing number example come happiest place earth ” orlando, fla. new york time report 250 data system employee disney world called boss ’ office. thought getting bonuses. really got shock lifetime. [ a ] bout 250 disney employee told late october would laid off. many job transferred immigrant temporary visa highly skilled technical workers, brought outsourcing firm based india. next three months, disney employee required train replacement job lost, ” according paper. ‘ i couldn ’ t believe could fly people sit desk take job exactly, ’ said one former worker, american 40 remains unemployed since last day disney jan. 30. ‘ it humiliating train somebody else take job. still can ’ t grasp it, ’ reported new york times. the disney case unique. los angeles, 400 information technology employee southern california edison learned laid would train h1b visa replacements. ‘ they bringing people couple years ’ experience replace u train them, ” said one longtime worker …. one job filled india job edison employee wasn ’ t already performing, ” said, reported computerworld magazine, interviewed several laidoff employees. in columbia, mo., local television station kmiz reported last month republican sen. charles grassley iowa investigating allegation ibm engaging firing american worker replacing h1b visa holders. a local abc affiliate sacramento, calif., state capital, investigating many american lost california state job foreign hb1 visa holders. in response new york time report disney allegations, democratic sen. bill nelson florida called department homeland security investigate potential misuses ” program. answer hard find. ron hira, professor public policy rochester institute technology spoke npr issue. past
# True label:
# 2
# Predicted label:
# 1
# --------------------------------------------------
# Input text:
# in year supposed angry electorate, million frustrated voter put weight behind outsider presidential campaign donald trump bernie sander continue back congressional incumbent ousting one far hundred 2016 primary contests. the lone victim pennsylvania democratic rep. chaka fattah, ouster appeared questionable ethic frustration washington insiders. 11term congressman facing 29count federal indictment related racketeering, bribery mail fraud. the year outside candidate neat, tidy package put medium certain extent, ” david payne, republican strategist partner vox global, said week. it ’ s part story. look insider picking 60 percent vote. ” payne argues house district carefully constructed ” state party official others remain stable ” primary race competitive. to sure, member congress rarely lose primary race, incumbent ( typically ) face challenge candidate political party. over past three election cycles, 17 congressional incumbent ousted primary four house member 2014, five house member one senator 2012, four house member three senator socalled 2010 tea party revolution. with claim many seven upset 2010 primaries, conservative, grassroots tea party movement likely success 2016 electorate ousting incumbents. the 2010 defeat threeterm utah gop sen. bob bennet, reliable conservative, tea partybacked mike lee indeed rattled political class. but race seems stick voter others 2014 upset house majority leader rep. eric cantor. virginia republican member house leadership stunningly upset year dave brat, firsttime candidate tea party support. the postscript race suggests cantor paid little attention district. but beyond getting ousted socalled ideological purity, ” capitol hill lawmaker also often lose primary amid ethic scandal, result redistricting ( include eight 2012 ), accidental candidates ” get elected when, example, party ’ s top candidate unexpectedly drop out. this year, trump, billionaire businessman firsttime candidate, beat dozen republican lawmaker former elected official become party ’ s presumptive presidential nominee. and sanders, selfdescribe democratic socialist, kept insurgent campaign alive democratic primary portraying frontrunner hillary clinton washington wall street insider. louis jacobson columnist magazine governing ” senior correspondent tampa bay times ’ politifact ” suggested friday angry electorate indeed exists, big personalities ” national stage appear capable getting voter riled polling stations. i ’ m seeing whole lot it ” gubernatorial statelevel races, jacobson said. he argued congressional district become blue red year it ’ s nearly impossible challenger conservative liberal sitting house member. suggested congress appears amorphous ” among voters, tend know presidential candidate, result targeted anger. such theory might help explain hill lawmaker continue win 2016 primary despite historically
# True label:
# 2
# Predicted label:
# 0
# --------------------------------------------------
# Input text:
# the rev. franklin graham said monday activist judge blame legalization gay marriage. graham, son rev. billy graham ceo samaritan purse billy graham evangelistic association, specifically referring home state north carolina. sixtyone percent state residents, according christian post, samesex marriage federal judge state recently overturned ban practice anyway. its sad judge able overrule the people, graham told wcnc charlotte, nbc affiliate, monday. democracy, people spoke, seeing activist judge across country overturning the people. saw california. seeing north carolina now. dont know take place. last friday, u. s. district court judge max o. cogburn jr. struck north carolina ban gay marriage, move followed supreme court announcement would hear appeal regarding legalization gay marriage. the court determines north carolina law prohibiting samesex marriage unconstitutional matter law, cogburn wrote ruling. issue court neither political issue moral issue. legal issue clear matter settled law fourth circuit north carolina law prohibiting sex marriage, refusing recognize sex marriage originating elsewhere, and / or threatening penalize would solemnize marriages, unconstitutional. cogburn appointed position president barack obama. lgbt family north carolina treated equal law north carolina — day many fought hard for, said rev. jasmine beachferrara, executive director campaign southern equality, friday ruling. celebrate knowing shameful chapter north carolina history passed. time know still fired simply gay north carolina. protection discrimination workplace next step push full equality.
# True label:
# 2
# Predicted label:
# 1
# --------------------------------------------------
# Input text:
# a popular meme describing monotonous routine coronavirusinduced homestays repeat dolly parton ’ s 9 5 ” intro : tumble bed stumble kitchen... tumble bed stumble kitchen... tumble bed stumble kitchen. ” food american mind ten million coop home prevent spread covid19. restaurant closed except takeout. grocery stores, deemed essential businesses, open, empty shelf show evidence panic buying across country. news outlet compiled list store open operating hours, clarifying reinforcing fundamental concern : grocery store close coronavirus pandemic? more existentially terrifying, perhaps : food supply chain break entirely? some store begun closing, despite essential businesses. trader joe ’ s least temporarily shuttered store staffer tested positive coronavirus. supermarket clerk begun succumb virus italy, u. s. store taken installing protective barrier shopper cashiers. entire government also hoarded food : kazakhstan banned international sale wheat flour, one world ’ s largest exporters, serbia instituted similar measures. meanwhile, propublica reported saturday, disturbing sign meatindustry worker feeling pressured stay job despite illness, food safety inspector new york recently succumbed coronavirus. but least now, panicked shopper bare shelf speak le lack food shifting demand lagging logistics, expert told daily beast. restaurant needed far le food closed ; individual people family decided needed far faced week home. food inventory actually high, according government data. the empty shelf largely matter moving it. it ’ s severalweeks process. supply chain take time catch up, ” said professor yossi sheffi, director mit center transportation logistics. even wuhan, china, pandemic began, resident faced localized food scarcity peak covid ’ s rage there. courier delivered food supply even faced concerted lockdown. in lighthearted sign shortage nowhere near disasterlevel, american shopper still choice leave behind whole shelf plantbased hot dog perhaps le desirable item even pick staple clean. the timestamp picture like always evening. overnight, restocked, ” sheffi said. may get favorite cereal, you ’ ll get cereal. ” his take echoed assurance government officials. there currently nationwide shortage food, despite localized report shortages, ” deputy fda commissioner frank yiannas wrote guideline published tuesday. food production manufacturing — for people animals — are dispersed throughout u. s. currently widespread disruption reported supply chain. ” sheffi said he ’ s focusing attention medical supply chain. dire shortage protective equipment led healthcare worker exposed become sick droves, he ’ s advising hospital company best way manage
# True label:
# 0
# Predicted label:
# 2
# --------------------------------------------------
# Input text:
# robert spencer — controversial author founder blog jihad watch — spoke tuesday stanford university invitation university college republicans. event proceeded relatively peacefully, minimal disruption. but many believed stanford never allowed spencer speak first place, including group stanford faculty student published open letter urging university block spencer talk. the argument letter author fully support principle academic freedom allows u disagree issues, spencer view islam debatable fundamentally dehumanizing. whenever claim made identity group inherently le worthy full personhood — whether claim made people muslim, rohingya, jewish, black, trans gender nonconforming, bosnian, queer, immigrants, mexican, etc. — always unacceptable. this quickly become one common, insidious, dangerously slipperyslope argument free speech college campus beyond. let set aside moment even truly dehumanizing speech protected first amendment. ( although stanford public university, california leonard law applies protection first amendment nonsectarian private schools. ) reality campus debate controversial issue will, proponent viewpoint, unjustly demean value someone identity. consider student university florida earlier week vandalized promotional material upcoming prolife event campus put university young american freedom. facebook message bragging vandalism, one student wrote : poured water lovely creation insult entire major life experiences! to others, opposing view immigration policy attack humanity undocumented immigrants. nyu professor provost ulrich baer wrote last spring new york times, [ s ] ome topics, claim human being definition inferior others, illegal unworthy legal standing, open debate people cannot debate terms. meanwhile, laura kipnis — feminist northwestern professor twice investigated northwestern title ix violation criticism campus sexual politics — spoke wellesley college, faculty school commission ethnicity, race, equity issued statement calling change outside speaker policy. speaker like kipnis, statement said, require student invest time energy rebutting speaker arguments … order affirm humanity. when heather mac donald, vocal critic black life matter movement, spoke last spring claremont mckenna college, violent protester attempted shut event, forcing manhattan institute fellow give talk via livestream. three student nearby pomona college issued statement saying [ t ] he idea search truth involves entertaining heather mac donalds hate speech illogical. engaged, heather mac donald would debating mere difference opinion, right black people exist. and forget reaction yale student erika christakiss thoughtfully worded email, october 2015, questioning whether institution higher education police halloween costume adult college students? student blasted christakis husband, nicholas, failing create safe space them, despite reputation nurturing residence mentors. one article describing world shaken christakiss offensive email, yale student wrote
# True label:
# 2
# Predicted label:
# 0
# --------------------------------------------------
# Input text:
# george w. bush support reelection donald trump, according people familiar thinking, new york time reported saturday. the paper said former president texas governor wont vote trump reelection brother, former florida gov. jeb bush, isnt sure hell vote. paper spotlight several member republican party dissenting party lines, though bush prominent texas politician mentioned. freddy ford, spokesman bush, told texas tribune bush would steer clear speaking publicly presidential vote called new york time assertion false. this completely made up, ford said email. retired presidential politics indicated vote. it unclear whether bush instead voting joe biden, trump democratic rival. bush brother — parents, former president george h. w. bush first lady barbara bush — said 2016 didn ’ t vote trump. trump endorsed jeb ’ s son, george p. bush, ran reelection texas land commissioner 2018. 2014, jeb bush ran president ( a race lost trump ), george p. told texas tribune ’ s evan smith wouldn ’ t endorse father. the paper said u. s. sen. mitt romney wont endorse president, cindy mccain, widow u. s. sen. john mccain. military leader sharing misgivings, too. william mcraven, former university texas system chancellor retired navy admiral, vocally dismissive trump past. told time trump isnt qualified office. president trump shown doesn ’ t quality necessary good commander chief, ” said. texas sen. ted cruz also highlighted unwavering supporter ” trump.
# True label:
# 0
# Predicted label:
# 2
# --------------------------------------------------
# Input text:
# george washington one founding member christ church alexandria, virginia, buying pew no. 5 church opened 1773 attending two decade whenever rode north mount vernon business town. this weekend, church announced pulling memorial plaque onetime vestryman country ’ s first president, saying another famous parishioner, robert e. lee, become controversial chasing away wouldbe parishioners. while acknowledging friction ” decision, church ’ s leadership said plaques, attached front wall either side altar, relic another era business church proclaims motto welcome — exceptions. ” the plaque sanctuary make presence feel unsafe unwelcome. visitor guest worship u choose return receive unintended message prominent presence plaques, ” church leader said letter congregation went last week. the decision also announced parishioner sunday. the backlash swift, church ’ s facebook page turning battleground. supporter praised church courageous ” stand, critic compared leader episcopal church leader taliban islamic state. church leader said debated long time, rev. noelle yorksimmons, rector, said email washington time vote vestry unanimous. plaque come next summer, leadership determines another place them. for now, lee memorial, size grave marker, stand right altar, reading gold lettering, memory robert edward lee. ” washington plaque left says : memory george washington. ” they erected 1870, month lee ’ s death, bit sensation time, earning mention newspaper massachusetts san francisco. account said memorial paid subscription citizen alexandria. the church also small metal marker washington family pew location lee confirmed, information comment posted two men ’ s life church. lack detail part problem leaders, said memorial didn ’ t explain two famous parishioners ’ memorial presence. because sanctuary worship space, museum, appropriate way inform visitor history plaque provide additional context except inperson tour provided docents, ” church leader said. it ’ s clear church could divorce washington even wanted to. website tout church george washington worshipped ” display picture famous patron. a original benefactor, washington bought pew no. 5 church opened 1773. vestryman contributed church throughout life, according washington paper project. family considered church important enough donated one bible death. lee attended christ church beginning age 3, moved stratford alexandria. church integral family mary custis lee, daughter, left church $ 10, 000 upon death 1918. money used begin church ’ s endowment. church leader say whether attempt return $ 10, 000 gift lee ’ s daughter. the church ’ s senior junior warden didn ’ t answer question decision, neither ms. yorksimmons, rector. instead, emailed brief statement saying decision unanimous vote ” vestry.
# True label:
# 2
# Predicted label:
# 1
# --------------------------------------------------
# Input text:
# cocacola considering move growing market cannabisinfused drinks. coke said statement monday closely watching growth cbd, nonpsychoactive component marijuana, ingredient called functional wellness beverages. the space evolving quickly, coke ( ko ) said. decision made time. cbd, produce high user, used medical purposes, including easing inflammation, pain nausea. coke interest first reported bloomberg, said company talk aurora cannabis, canadian cannabis company. aurora also expressed interest cannabis drinks. neither would comment possible deal. there much happening area right think incredible potential, said aurora spokesperson heather macgregor. story like validation massive global potential cannabis industry. constellation brand ( stz ), maker corona beer, svedka vodka casa noble tequila, announced last month investing additional $ 4 billion canadian cannabis company canopy growth ( cgc ). a number canadian cannabis companies, including cronos ( cron ) medmen enterprise ( mmnff ), trade u stock exchanges, american company taken stakes. and lagunitas, craft beer label brewing giant heineken ( heiny ), already drink infused thc, marijuana active ingredient, produce high. purchased marijuana dispensary california. both cannabis cbd still illegal united state federal law, even though number state legalized marijuana. prohibition cbd strictly enforced. thirdparty seller offering cbdbased product amazon ( amzn ), example. still, unlikely major company like cocacola would offer product infused cbd united state federal law changes, said kris krane, president 4front, firm advises company legality marijuana expert cannabis law. said would expect coke would develop product first sale canada, readying united state legal. i cant imagine theyre 35 million people canada, clearly eye u market, said krane. coke could well positioned capture market share cbd marijuana product become legal, said bonnie herzog, analyst well fargo. said note client monday coke positioning longterm. estimate cannabisinfused drink could become $ 50 billion annual market united state nearly half size $ 117 billion market u beer sales. both coke rival pepsico trying expand business beyond traditional soft drink people drink le soda health concerns. last week, coke announced deal buy costa coffee $ 5 billion. canada process legalizing recreational use marijuana. drug still illegal u federal law, although state decriminalized it. in june, u food drug administration approved epilepsy treatment epidiolex, first cannabisbased drug allowed united states. includes cbd well.
# True label:
# 0
# Predicted label:
# 1
# --------------------------------------------------
# Input text:
# ...
# True label:
# 2
# Predicted label:
# 1
# --------------------------------------------------
# Input text:
# about 100 american well thousand european joined islamic state iraq syria ( isis ). theory, socalled foreign fighter pose major threat western homelands : passport give freedom slip back home, bringing battlefield experience antiwestern extremism them, potentially plot attacks. according new york times, senior american counterterrorism official believe becoming harder track american traveled conflict syria iraq drag on. it worth taking deep breath. risk american coming home iraq syria pulling attack us, something intelligence agency take seriously, something american probably much fear from. there risk europe, still plenty reason think westerner joining isi far le problem might think. there arent many people coming home plot attack about 2, 000 3, 000 westerner traveled syria fight one group another conflict there, according thomas hegghammer, director terrorism research norwegian defence research establishment. actual number people ground lower right now, says, quite returned. so far, hegghammer says, look like blowback effect going quite low. according hegghammers research, one nine western jihadis fought foreign war come home plot attacks. say estimate come lowend estimate total number foreign fighters, ratio return attempt attack west likely one 20 one 100. date, number much lower volunteer iraq syria. thereve four six plots, involving five ten people, west. thats 2, 0003, 000 volunteers, blowback rate one several hundred, hegghammer concludes. vanishingly small. so far, simply arent many isi volunteer coming back west plan terrorist attacks. according hegghammer, thats partly isi simply isnt prioritizing attack united state europe. theyre busy fighting preserve caliphate spend lot time abroad. these guy easy catch the conflict syria iraq arent yet. seems likely that, conflict start winding entering sort stasis, western volunteer would become likely return home stir trouble. but even then, theyre nearly dangerous might think. were going know guy are, going watch closely transit home, mccants, director project u relation islamic world brookings institution, told me. mccants admits thats hard catch isi volunteer way syria iraq. however, much, much easier identify way home. theyve gone in, mccants says, u intelligence going find them. partly thats u western country obsessive monitoring border keenly aware threat, also jihadis love talk social media. ive told people u intel publicly posted statement twitter absolute gold mine, says. the atlantic ocean u friend here. airport robust system detecting returning fighters, according mccants. hard get back united state iraq
# True label:
# 0
# Predicted label:
# 1
# --------------------------------------------------
# Input text:
# soros fund management, private investment management fund george soros, generally leftleaning supportive democratic candidates, sometimes farleft financier soros fund give candidate ( r ) next name. earlier week, took look koch brother examined instance partisan narrative doesnt exactly match reality – though often perceived partisan republicans, koch industry give money handful democratic politician years. and align koch values, always doctrinaire republican ( e. g. open borders, increased immigration, drug decriminalization, gay marriage, right choose ), sometimes ( e. g. financial deregulation lower corporate tax rates ), happy koch industry various arm koch network fork cash campaign advertising. according public fec donation record made available opensecrets. org, 2018 midterm election cycle, soros fund management totaled nearly $ 207, 000 donations, part money going democrat like claire mccaskill, tim kaine, kirsten gillibrand, elizabeth warren. but republican favored campaign contribution well. includes u. s. senator john barrasso ( rwy ), who received $ 5, 000 contributions ; u. s. rep. brian fitzpatrick ( rpa ), who also received $ 5, 000 campaign donations ; u. s. senator roger wicker ( rms ), who also bagged cool five grand soros fund management ; even senator ted cruz ( rtx ), who given $ 2, 500 towards reelection campaign ; senator lindsey graham ( rsc ), who received $ 1, 000. in case didnt know it, political contribution individuals, companies, private organization public data collected published fec, opensecrets. org project nonpartisan, nonprofit center responsive politics, make information available easytonavigate platform. the center founded 1983 two retired u. s. senators – frank church, democrat idaho, hugh scott republican pennsylvania. opensecrets important tool discerning voter spend minute take see political campaign donation coming theyre going to. independent voter discerning – thats dont vote straight party line every ballot. make determination candidate prefer. following money important making determination checking voting records, past career achievements, researching public statement candidate made public policy. one important thing remember powerhouse billionaire like george soros david koch donation may seem entirely partisan maybe even strictly ideological, enormous stake special interest private business magnates. may picked team play for, end buying influence congress make sure policy swing way possible protect lucrative profit businesses – least dont swing hard. george soros news today coauthoring oped titled, better bailout
# True label:
# 1
# Predicted label:
# 2
# --------------------------------------------------
# Input text:
# republican complained medium bias decades. donald trump, whose attack press escalating, staking position much extreme predecessors. in trump world, journalist really hillary clinton campaign worker disguise, collaborating clinton conspiracy rig election. this marked change past republican complaint press. fact, much alleging lack objectivity. instead talking favoritism among journalist toward candidate cause, trump making extreme claim : politics journalism thing, journalism professor jay rosen told cnnmoney. way thinking, medium left equal sign them. rosen, teach new york university writes pressthink blog, said trump statement another way breitbartian world view triumphed. trump medium ally encouraged supported way thinking. fox host sean hannity thursday called medium extension clinton. it become common trump falsely accuse journalist collusion clinton. the failing @ nytimes reporter dont even call u anymore, write whatever want write, making source along way! — donald j. trump ( @ realdonaldtrump ) october 15, 2016 in recent days, trump cited stolen cache document published wikileaks claim medium collaborates clinton. but document show isolated example questionable journalistic behavior systemic fraud alleges. trump also tried deny legitimacy county esteemed newsrooms. reporter new york times, theyre journalists, theyre corporate lobbyist carlos slim hillary clinton, trump said friday. railed paper publishing account two woman say trump groped them. the election rigged corrupt medium pushing completely false allegation outright lie effort elect president, trump said saturday. related : trump betrayed first amendment values, journalism advocate say accusation bias old craft itself. medium watchdog left right seek hold journalist accountable. but trump accusation different. suggest see difference practice journalism practice politics. trump reflecting growing view right journalist nothing democratic operative bylines, conservative blogger glenn reynolds like say. rosen said trump supporter adopt point view essentially opted journalism. many journalist do, fact, dislike trump resent campaign relentless medium criticism. viscerally fear candidate long term impact words. critic charge antipathy bleeds news coverage. but individual opinion trump campaign trail conduct wholly different institutional conspiracy elect clinton. newsroom inherently competitive places, resistant collaboration, even would benefit them. news outlet market driven : many outlet sound same, business incentive create alternatives. but trump doesnt acknowledge that. trump attack serve multiple purposes. targeting messenger, attempting discredit message inoculate avalanche critical news stories. also energizing supporter come rally cheer social media. trump medium tirade met chant cnn suck rally week. at one event friday, trump said stop sick media. the medium is, indeed,
# True label:
# 0
# Predicted label:
# 2
# --------------------------------------------------
# Input text:
# it display kind openmindedness conservative begging for. no one national review ever guilty failing, course, conservative tendency grumpy, grouchy, grumbly. u hear happy holidays ” mutter darkly, war christmas begun. ” u see two men holding hand produce aisle think, must cram homosexualist agenda throat? ” u vow never return movie unless john wayne resurrected. sometimes conservative call cultural change, change actually follows response... suspicious silence. surely don ’ t mean it, mumble. won ’ t last. gotta kind trick. stretching back across eons, conservative asking consideration new york times, still influential news outlet united states. year ago, got it. notably opinion department, change direction gray ladyland. huzzahs right? after 2016 election, leader time realized profoundly misguided strength donald trump movement. typical coverage headline like these : democrats, looking past mere victory, hope end trump phenomenon ” ( august 3, 2016 ) flip house, big would clinton victory margin need be? ” ( october 24, 2016 ). coverage thencandidate trump focused almost exclusively unappealing was. credit, time realized error. two day election, executive editor dean baquet told paper ’ s medium columnist jim rutenberg, mea culpa journalist journalism, it ’ s we ’ ve got much better job road, country, talking different kind people people talk — especially happen new york – based news organization — remind new york real world. ” expecting time become completely neutral news outlet like expecting vatican bookshop start selling christopher hitchens ’ s god great. i ’ ve reading paper 30 year ( grumbling time, often outright harrumphing ), believe last year marked first time paper showed awareness confirmation bias — bubble problem. james bennet, editorialpage editor brought board march 2016, hired major rightofcenter columnist, bret stephens, wall street journal last april 12. two day later, took significant step hired bari weiss, oped writer editor, also journal, writ bring rightleaning thinker paper. say least, time ordinarily habit poaching talent leading conservative opinion section country. yet since weiss ’ s hire, conservative commentary flourished time like never before. days, hardly week go without column naomi schaefer riley charles kesler john yoo benjamin domenech stephen moore yuval levin. great people, housebroken conservative love curl liberal laps, they ’ ve appeared time since beginning year. there ’ s still big hole times ’ opinion section : hardly ever one encounter protrump
# True label:
# 2
# Predicted label:
# 0
# --------------------------------------------------
# Input text:
# u. s. supreme court justice ruth bader ginsburg said split 44 decision shorthanded high court left important public policy issue air, including president immigration plan, likely revisited court future. addressing gathering attorney new mexico friday, ginsburg highlighted impact recent split decision supreme court left place lower court ruling immigration, organized labor fee ability native american tribal court decide controversy involving visitors. the supreme court working without ninth justice since death justice antonin scalia february. senate republican refused hold confirmation hearing obamas supreme court nominee ahead presidential election. ginsberg said eight justice good enough decide several crucial cases. when evenly divided, equivalent denying review, ginsburg said. important issue four case unable decide, come back one president immigration policy. the 83yearold brooklyn native, appointed supreme court 1993 bill clinton, made mention friday ongoing presidential campaign controversial comment last month gop nominee donald trump. in series medium interview july, ginsburg said want think possibility trump presidency, describing gop presidential contender faker really ego. later said regretted illadvised public criticism. member new mexico state bar association guest flocked casino resort north santa fe hear ginsburg, anchor liberal wing current eightmember court counterweight conservative chief justice john roberts. the supreme court deadlocked decision march threatened ability publicsector union collect fee worker dont want join union pay collective bargaining activities, victory organized labor. in june, 44 tie among justice effectively ended federal program would shielded million undocumented immigrant deportation work legally u. s.
# True label:
# 2
# Predicted label:
# 1
# --------------------------------------------------
# Input text:
# the first batch vote counted california poll close tonight 3. 7 million ballot already mailed — chunk contain zombie votes ” president. not vote literal zombies, course — it ’ s term politico use describe vote cast candidate pulled plug campaigns. three democratic contender past days. paul mitchell, electoral research firm political data inc., project 350, 000 400, 000 californian already voted mail candidate dropped out. suspect number could grow half million. even so, voter appeared waiting last minute cast ballot ( and perhaps make minds ). although 16 million californian received mail ballot, le quarter ballot returned eve election. because ballot need postmarked tomorrow arrive friday counted, official preparing possible problem delay day week final outcome close races. that ’ s one reason advocated voting ahead time — strategy campaign urged well, way lock supporter win ” optic night early strength vigorous showing early vote tabulations. but many voted early pete buttigieg, amy klobuchar, andrew yang tom steyer probably tad regretful arguably wasted votes. the state say bad. vote cast mailed in, going back changing mind. michigan spoiled ballot rule, allows voter get new ballot candidate chose dropped out. california plan b option. and implication might candidate still running? vote democratic candidate quit affect many delegate remaining candidate allotted. party rule dictate candidate must earn 15 % statewide vote get statewide delegates, also candidate must earn 15 % vote state ’ s congressional district order receive delegate apportioned district level. that mean zombie votes ” could cause candidate miss 15 % threshold. mitchell used michael bloomberg hypothetical. bloomberg hypothetically received 13. 8 % vote, candidate longer running also receive percentage vote, race could easily gotten bloomberg top 15 %. ” but since vote still counted delegate math, ” said, bloomberg could theoretically stay 15 % candidate sucked votes. vote count calculations. ” it ’ s also possible candidate dropped nonetheless exceed threshold enough win delegate certain congressional districts. delegate would chosen excandidate expected vote first ballot democratic national convention. a anticipated flood sameday voting, either person mail, it ’ s difficult say precisely candidate stand benefit most. joe biden, instance, buoyed robust victory south carolina primary stream quitting candidate — klobuchar, buttigieg beto o ’ rourke among — endorsed him. californian didn ’ t vote early may swayed good news biden. conversely, former vice president lost momentum propulsion among californian already voted mail time trailed contenders. heading final hour california primary, latest available public poll still indicated bernie sander significant lead. poll
# True label:
# 1
# Predicted label:
# 0
# --------------------------------------------------

# %%
sources_analysis.to_csv('bert_fine_tuning_wrong guess(7.21.24).csv', index=False)
