# %%
# %%capture
# !pip install tensorflow-datasets==4.8 --quiet
# !pip install tensorflow==2.15.0 --quiet #15 13
# !pip install tf_keras==2.15.0 --quiet
# !pip install tensorflow-text==2.15.0 --quiet #15
# !pip install pydot --quiet
# !pip install transformers==4.17 --quiet
# !pip install -U scikit-learn

# %%
#Tensorflow libiries
from tensorflow import keras
from tensorflow.keras.layers import Embedding, Input, Dense, Lambda
from tensorflow.keras.models import Model
import tensorflow as tf
import tensorflow.keras.backend as K
import tensorflow_datasets as tfds

#Transformers - BERT from huggingface
from transformers import BertTokenizer, TFBertModel
from transformers import AutoTokenizer, TFAutoModel
from transformers import logging
logging.set_verbosity_error()
from transformers import AutoConfig
from tensorflow.keras.callbacks import EarlyStopping

#NLP libiries
import sklearn as sk
from sklearn.metrics import classification_report
import os
import nltk
from nltk.data import find

#data process
import re
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import multiprocessing
import pandas as pd
import math
from bs4 import BeautifulSoup
import os
import json

# %%
#loading the pre-trained tokenizer and model
distillroberta_nli_tokenizer = AutoTokenizer.from_pretrained('matekadlicsko/distilroberta-nli')
distillroberta_nli_model = TFAutoModel.from_pretrained('matekadlicsko/distilroberta-nli', from_pt=True)
# Out:
# Downloading:   0%|          | 0.00/1.22k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/780k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/75.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/167 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/894 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/313M [00:00<?, ?B/s]

# %%
#load the dataset with error handling
try:
    train_df = pd.read_csv('balanced_train_data(Revised)-2.csv')
except pd.errors.ParserError as e:
    print(f"Error reading CSV: {e}")
    # Print the lines around the problematic row
    with open('full_train_data(Revised).csv', 'r') as f:
        lines = f.readlines()
        for i in range(17622, 17626):
            if i < len(lines):
                print(lines[i])

test_df = pd.read_csv('balanced_test_data(Revised)-2.csv')

# Adjust pandas display settings to show all rows and columns
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_colwidth', None)  # Show full content of each column
pd.set_option('display.width', None)  # Auto-detect width of the display

# %%
train_df.head(1)
# Out:
#                                           title        date  \
# 0  want shrink wage gap? help parent care kids.  2016-04-12
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0  norway may seem like odd subject equal pay day united states. people, exactly subject help kickstart move reduce stubborn income gap men women. in early 1990s, norway tried something first europe: four week mandatory paternity leave workers. addition changing country’s cultural attitude toward childrearing (fathers taking several month care child commonplace) now10 week daddy leave” economic side effect well. country’s gender wage gap shrunk half. in 1991, working woman norway made 20 percent le men, according data organization economic cooperation development (oecd). 2010, 8.3 percent. holding policy norway panacea social issue u problematic. norway smaller, socially progressive (with heavily subsidized national daycare system), centralized government. u observes equal pay day april 12, advocate gender equality public private realm giving credence idea supporting woman home inextricably linked supporting workplace. specifically, they’re making case investment child care could help shrink pay gap – added bonus growing economy. according analysis leftleaning economic policy institute released earlier month, access affordable child care would help increase participation woman labor force, thereby growing economy estimated $210 billion year. the gender wage gap definitely driven part wage penalty faced woman likely extended period workforce caring sick relatives,” josh bivens, research policy director epi, writes via email. giving parent greater access highquality, affordable child care early childhood education, make easier want work participate labor force…. increase size labor force, turn boost gdp.” some business business group agree. subsidized child care encourage lowskilled parent maintain connection labor force upgrade skill education, thereby contributing economic growth productivity longer term,” read 2015 analysis state childcare cost committee economic development, nonprofit businessled public policy organization arlington, va. recommends expanding certain childcare credit worker employers. equal pay day united state observed every year day woman catch financially annual pay male counterparts. year’s observance fall april 12, meaning took american woman one year 103 day earn american men earned 2015. the day got plenty political attention, too. president obama dedicated monument women’s equality tuesday, hillary clinton took part panel pay transparency included megan rapinoe, one u women’s soccer star filed complaint equal employment opportunity commission u soccer federation unfair pay practice last month. per census bureau data, woman american workforce make 79 cent every dollar white man makes, it’s worse woman color (60 cent black women; 55 cent latino women). shortfall cost american woman combined $500 billion annually, according report released tuesday national partnership woman & families. if gap eliminated, average, working woman united state would enough money approximately: 83 week food family; seven month mortgage utility payments; 11 month rent; nine year birth control,” report reads. the wage disparity men woman barely changed past two decades, say national partnership vice president vicki shabo. 2006, woman made 77 cent every dollar earned white males, says. on family leave, least, small promising movement several fronts. january poll found 80 percent likely voters, including 94 percent democrats, 80 percent independents, 65 percent republican characterized thing like equal pay, paid time off, affordable child care good nation. issue become talking point presidential candidate politician side aisle. three states, rhode island, california, new york, well city like washington, d.c., san francisco, introduced paidleave rules. major tech companies, twitter netflix etsy, recent month falling introduce increasingly competitive inclusive paidleave allowance employees. there still obstacles, ms. shabo says. 13 percent u worker access paid leave all, look state population need, taken action, there’s pretty sub ...
#
#    bias bias_text                     source
# 0     1    center  Christian Science Monitor

# %%
print(f"basic train_df info: ",train_df.shape)
# Out:
# basic train_df info:  (7740, 6)

# %%
test_df.head(1)
# Out:
#                        title        date  \
# 0  opinion: party bad faith?  2017-07-17
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    content_original  \
# 0  senate majority leader mitch mcconnell capitol hill (aaron p. bernstein/reuters) despite repeated promises, republican can’t seem repeal obamacare. if republican attempt repeal replace obamacare ultimately fails, lesson wage political bad faith. the bill plenty obstacles, including sheer inertia obamacare status quo fact one made public case republican legislation. effort also suffers mismatch longtime public posture republican (obamacare must fully repealed) private misgiving (do really this, even partially?). advertisement advertisement it’s republican said year would repeal obamacare; actually voted it. december 2015, bill passed senate stringent version struggling gop support. 2015 bill tried repeal obamacare (although fell short goal), current bill attempt repeal replace, i.e., forge republican alternative. only two republican senator voted 2015 repeal, susan collins maine, still no,” mark kirk illinois, senate. everyone else board, celebrated righteous blow obamacare. winston churchill said nothing exhilarating getting shot without consequence. republicans, nothing exhilarating repealing obamacare without consequence. the repeal bill inevitably got vetoed president barack obama. republican congressional leader thought could pick left off. failed account changed — difficult — dynamic republican white house ready eager sign whatever get desk. advertisement advertisement the prospect current bill clouded hesitance medicaid moderates, republican senator state accepted obamacare expansion program. legislation hardly dickensian front. allows state continue expansion, but, time, brings level federal funding new population level rest medicaid (years now, also establishes new per caput formula medicaid). 2015 law tougher expansion — simply ended two year — yet today’s handwringers voted it. perhaps disturbed coverage number congressional budget office produced current bill? according cbo, would lead 22 million fewer people insurance. earlier repeal bill, per cbo, would led 32 million fewer people insurance. advertisement perhaps think current bill generous? fact senate bill unveiled week ago spends roughly $600 billion replacing obamacare, $600 billion december 2015 bill. since revised spend even more, scale back tax cuts. advertisement a publication health affair starkly noted 2015 legislation time, would end premium tax credits, costsharing reduction payments, medicaid expansion, small business tax credit — is, assistance aca give low moderateincome americans.” (rand paul, whose shtick libertarian purity, guilty hypocrisy. portrays 2015 bill preferable current version, opposes fully repealing obamacare regulations. 2015 bill didn’t touch major obamacare regulations.) advertisement all plan b endorsed president donald trump — revert repealonly bill current bill fails — nonstarter. aren’t 50 republican vote today’s relatively generous bill, won’t 50 vote anything like passed year half ago. unless, perhaps, trump promise veto it, senate republican consider blissfully consequencefree vote. read more: if republican nothing obamacare, voter punish them republicans’ grim healthcare fairy tale the republican healthcare mistake — rich lowry editor national review. reached via email: comments.lowry@nationalreview.com. © 2017 king feature syndicate
#
#    bias bias_text      source
# 0     2     right  Rich Lowry

# %%
print(f"basic test_df info: ",test_df.shape)
# Out:
# basic test_df info:  (3318, 6)

# %%
# extract the train and test text from both dataframes
train_text = train_df['content_original']
train_text_labels = train_df['bias']

validate_text = test_df['content_original'][0:1105]
validate_text_labels = test_df['bias'][0:1105]

test_text = test_df['content_original'][1105:]
test_text_labels = test_df['bias'][1105:]


print(f"size of training dataset: ",len(train_text))
print()
print(f"size of valid dataset: ",len(validate_text))
print()
print(f"size of testing dataset: ",len(test_text))
print()
print(f"Left with Label 0 ")
print(f"Center with Label 1 ")
print(f"Right with Label 2 ")
# Out:
# size of training dataset:  7740
#
# size of valid dataset:  1105
#
# size of testing dataset:  2213
#
# Left with Label 0
# Center with Label 1
# Right with Label 2

# %%
MAX_SEQUENCE_LENGTH = 512

# %%
# tokenize the dataset, truncate at `max_length`,

#tokenizing the train text
x_train = distillroberta_nli_tokenizer(train_text.tolist(),
              max_length=MAX_SEQUENCE_LENGTH,
              truncation=True,
              padding='max_length',
              return_tensors='tf')
y_train = train_text_labels

#tokenizing the validate text
x_validate = distillroberta_nli_tokenizer(validate_text.tolist(),
              max_length=MAX_SEQUENCE_LENGTH,
              truncation=True,
              padding='max_length',
              return_tensors='tf')
y_validate = validate_text_labels


#tokenizing the test text
x_test = distillroberta_nli_tokenizer(test_text.tolist(),
              max_length=MAX_SEQUENCE_LENGTH,
              truncation=True,
              padding='max_length',
              return_tensors='tf')
y_test = test_text_labels

# %%
#BERT base uncased model configurations
config = AutoConfig.from_pretrained('matekadlicsko/distilroberta-nli')

config
# Out:
# RobertaConfig {
#   "_name_or_path": "matekadlicsko/distilroberta-nli",
#   "architectures": [
#     "RobertaForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 6,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "problem_type": "single_label_classification",
#   "torch_dtype": "float32",
#   "transformers_version": "4.17.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }

# %% [markdown]
# #BERT Uncase Model Fine-Tuning

# %%
def create_distillroberta_nli_classification_model(roberta_model,
                                     num_train_layers=6,
                                     num_classes = 3,
                                     hidden_size = 768,
                                     dropout=0.2,
                                     attention_probs_dropout_prob = 0.15,
                                     hidden_dropout_prob=0.15,
                                     learning_rate=0.00005):
    """
    Build a simple classification model with BERT. Use the Pooler Output for classification purposes
    """
    if num_train_layers == 0:
        # Freeze all layers of pre-trained BERT model
        roberta_model.trainable = False

    elif num_train_layers == 12:
        # Train all layers of the BERT model
        roberta_model.trainable = True

    else:
        # Restrict training to the num_train_layers outer transformer layers
        retrain_layers = []

        for retrain_layer_number in range(num_train_layers):

            layer_code = '_' + str(11 - retrain_layer_number)
            retrain_layers.append(layer_code)


        print('retrain layers: ', retrain_layers)

        for w in roberta_model.weights:
            if not any([x in w.name for x in retrain_layers]):
                #print('freezing: ', w)
                w._trainable = False

    input_ids = tf.keras.layers.Input(shape=(MAX_SEQUENCE_LENGTH,), dtype=tf.int64, name='input_ids_layer')
    #token_type_ids = tf.keras.layers.Input(shape=(MAX_SEQUENCE_LENGTH,), dtype=tf.int64, name='token_type_ids_layer')
    attention_mask = tf.keras.layers.Input(shape=(MAX_SEQUENCE_LENGTH,), dtype=tf.int64, name='attention_mask_layer')

    roberta_inputs = {'input_ids': input_ids,
                   #'token_type_ids': token_type_ids,
                   'attention_mask': attention_mask}

    roberta_out = roberta_model(roberta_inputs)

    #pooler_token = bert_out[1]
    cls_output = roberta_out[0][:, 0, :]
    dropout_output = keras.layers.Dropout(0.3)(cls_output)


    classification = tf.keras.layers.Dense(num_classes, activation='softmax',name='classification_layer')(dropout_output)

    classification_model = tf.keras.Model(inputs=[input_ids, attention_mask], outputs=[classification])

    classification_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                                 loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
                                 metrics='accuracy')

    return classification_model

# %%
#let's get a fresh instance of the bert_model -- good practice
distillroberta_nli_model = TFBertModel.from_pretrained('matekadlicsko/distilroberta-nli', from_pt=True)
distillroberta_nli_classification_model = create_distillroberta_nli_classification_model(distillroberta_nli_model, num_train_layers=6)
# Out:
# retrain layers:  ['_11', '_10', '_9', '_8', '_7', '_6']

# %%
#layer summary
distillroberta_nli_classification_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  attention_mask_layer (Inpu  [(None, 512)]                0         []
#  tLayer)
#
#  input_ids_layer (InputLaye  [(None, 512)]                0         []
#  r)
#
#  tf_bert_model_2 (TFBertMod  TFBaseModelOutputWithPooli   8211840   ['attention_mask_layer[0][0]',
#  el)                         ngAndCrossAttentions(last_   0          'input_ids_layer[0][0]']
#                              hidden_state=(None, 512, 7
#                              68),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  tf.__operators__.getitem_2  (None, 768)                  0         ['tf_bert_model_2[0][0]']
#   (SlicingOpLambda)
#
#  dropout_78 (Dropout)        (None, 768)                  0         ['tf.__operators__.getitem_2[0
#                                                                     ][0]']
#
#  classification_layer (Dens  (None, 3)                    2307      ['dropout_78[0][0]']
#  e)
#
# ==================================================================================================
# Total params: 82120707 (313.27 MB)
# Trainable params: 82120707 (313.27 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(distillroberta_nli_classification_model, show_shapes=True, dpi=90)

# %%
from tensorflow.keras.callbacks import EarlyStopping
# Early stopping callback to avoid overfitting issue
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=2,
    mode='max',
    restore_best_weights=True  # Restore model weights from the epoch with the best value of the monitored quantity
)

# %%
distillroberta_nli_classification_model_history = distillroberta_nli_classification_model.fit(
    [x_train.input_ids, x_train.attention_mask],
    y_train,
    validation_data=([x_validate.input_ids, x_validate.attention_mask], y_validate),
    batch_size=32,
    epochs=5,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/5
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model_2/bert/embeddings/word_embeddings/weight:0', 'tf_bert_model_2/bert/embeddings/token_type_embeddings/embeddings:0', 'tf_bert_model_2/bert/embeddings/position_embeddings/embeddings:0', 'tf_bert_model_2/bert/embeddings/LayerNorm/gamma:0', 'tf_bert_model_2/bert/embeddings/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/query/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/query/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/key/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/key/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/value/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/value/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._0/intermediate/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/intermediate/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._0/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/query/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/query/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/key/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/key/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/value/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/value/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._1/intermediate/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/intermediate/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._1/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/query/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/query/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/key/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/key/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/value/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/value/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._2/intermediate/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/intermediate/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._2/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._3/attention/self/query/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._3/attention/self/query/bias:0', 'tf_bert_model_2/bert/encoder/layer_._3/attention/self/key/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._3/attention/self/key/bias:0', 'tf_be ...
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model_2/bert/embeddings/word_embeddings/weight:0', 'tf_bert_model_2/bert/embeddings/token_type_embeddings/embeddings:0', 'tf_bert_model_2/bert/embeddings/position_embeddings/embeddings:0', 'tf_bert_model_2/bert/embeddings/LayerNorm/gamma:0', 'tf_bert_model_2/bert/embeddings/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/query/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/query/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/key/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/key/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/value/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/value/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._0/intermediate/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/intermediate/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._0/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/query/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/query/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/key/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/key/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/value/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/value/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._1/intermediate/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/intermediate/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._1/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/query/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/query/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/key/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/key/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/value/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/value/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._2/intermediate/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/intermediate/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._2/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._3/attention/self/query/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._3/attention/self/query/bias:0', 'tf_bert_model_2/bert/encoder/layer_._3/attention/self/key/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._3/attention/self/key/bias:0', 'tf_be ...
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model_2/bert/embeddings/word_embeddings/weight:0', 'tf_bert_model_2/bert/embeddings/token_type_embeddings/embeddings:0', 'tf_bert_model_2/bert/embeddings/position_embeddings/embeddings:0', 'tf_bert_model_2/bert/embeddings/LayerNorm/gamma:0', 'tf_bert_model_2/bert/embeddings/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/query/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/query/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/key/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/key/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/value/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/value/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._0/intermediate/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/intermediate/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._0/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/query/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/query/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/key/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/key/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/value/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/value/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._1/intermediate/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/intermediate/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._1/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/query/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/query/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/key/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/key/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/value/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/value/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._2/intermediate/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/intermediate/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._2/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._3/attention/self/query/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._3/attention/self/query/bias:0', 'tf_bert_model_2/bert/encoder/layer_._3/attention/self/key/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._3/attention/self/key/bias:0', 'tf_be ...
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model_2/bert/embeddings/word_embeddings/weight:0', 'tf_bert_model_2/bert/embeddings/token_type_embeddings/embeddings:0', 'tf_bert_model_2/bert/embeddings/position_embeddings/embeddings:0', 'tf_bert_model_2/bert/embeddings/LayerNorm/gamma:0', 'tf_bert_model_2/bert/embeddings/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/query/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/query/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/key/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/key/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/value/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/self/value/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._0/attention/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._0/intermediate/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/intermediate/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._0/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._0/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._0/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/query/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/query/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/key/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/key/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/value/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/self/value/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._1/attention/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._1/intermediate/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/intermediate/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._1/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._1/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._1/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/query/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/query/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/key/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/key/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/value/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/self/value/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._2/attention/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._2/intermediate/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/intermediate/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/output/dense/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._2/output/dense/bias:0', 'tf_bert_model_2/bert/encoder/layer_._2/output/LayerNorm/gamma:0', 'tf_bert_model_2/bert/encoder/layer_._2/output/LayerNorm/beta:0', 'tf_bert_model_2/bert/encoder/layer_._3/attention/self/query/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._3/attention/self/query/bias:0', 'tf_bert_model_2/bert/encoder/layer_._3/attention/self/key/kernel:0', 'tf_bert_model_2/bert/encoder/layer_._3/attention/self/key/bias:0', 'tf_be ...
# 242/242 [==============================] - 47s 179ms/step - loss: 1.4573 - accuracy: 0.3435 - val_loss: 1.0901 - val_accuracy: 0.3910
# Epoch 2/5
# 242/242 [==============================] - 41s 169ms/step - loss: 1.3908 - accuracy: 0.3469 - val_loss: 1.0944 - val_accuracy: 0.3910
# Epoch 3/5
# 242/242 [==============================] - 41s 170ms/step - loss: 1.4081 - accuracy: 0.3469 - val_loss: 1.0965 - val_accuracy: 0.3439

# %%
history = distillroberta_nli_classification_model_history.history

# Plotting accuracy
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history['accuracy'], label='Training Accuracy')
plt.plot(history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plotting loss
plt.subplot(1,2,2)
plt.plot(history['loss'], label='Training Loss')
plt.plot(history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
predictions_model= distillroberta_nli_classification_model.predict([x_test.input_ids, x_test.attention_mask])
predictions_model = tf.argmax(predictions_model, axis=-1)
predictions_model
# Out:
# 70/70 [==============================] - 11s 130ms/step
# <tf.Tensor: shape=(2213,), dtype=int64, numpy=array([2, 2, 2, ..., 2, 2, 2])>

# %%
print(classification_report(y_test, predictions_model.numpy(),
                            target_names=['Left ','Center','Right']))
# Out:
#               precision    recall  f1-score   support
#
#        Left        1.00      0.00      0.00       751
#       Center       0.00      0.00      0.00       572
#        Right       0.40      1.00      0.57       890
#
#     accuracy                           0.40      2213
#    macro avg       0.47      0.33      0.19      2213
# weighted avg       0.50      0.40      0.23      2213
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
def plot_confusion_matrix(y_true, y_pred, label_names):
    cm = tf.math.confusion_matrix(y_true, y_pred)
    cm = cm/cm.numpy().sum(axis=1)[:, tf.newaxis]

    plt.figure(figsize=(20,7))
    sns.heatmap(
        cm, annot=True,
        xticklabels=label_names,
        yticklabels=label_names)
    plt.xlabel("Predicted")
    plt.ylabel("True")

# %%
target_names=['Left ','Center','Right']
plot_confusion_matrix(y_test, predictions_model.numpy(), target_names)

# %%
roberta_wrong_guesses = np.where(y_test != predictions_model.numpy())

# %%
print(f'Number of Wrong Guesses: ',len(roberta_wrong_guesses[0]))
# Out:
# Number of Wrong Guesses:  456

# %%
#sampling 20 of the wrong precditions
wrong_guesses = [i for i in np.squeeze(roberta_wrong_guesses[0])]
decoded_wrong_guesses_text=[]

for i in wrong_guesses[:]:
  decoded_text = distillroberta_nli_tokenizer.decode(x_test['input_ids'][i], skip_special_tokens=True)

  # print("Input text:")
  # print(decoded_text)
  decoded_wrong_guesses_text.append(decoded_text)
  # print("True label:")
  # print(y_test.iloc[i])
  # print("Predicted label:")
  # print(predictions_model.numpy()[i])

  # print("-" * 50)

# %%
len(decoded_wrong_guesses_text)
# Out:
# 456

# %%
sources_analysis = test_df.loc[wrong_guesses]

# %%
sources_analysis['source']
# Count the occurrences of each source
source_counts = sources_analysis['source'].value_counts()

# Create a bar plot
plt.figure(figsize=(12, 6))
source_counts.plot(kind='bar')

# Customize the plot
plt.title('Distribution of Wrong Guess''Sources')
plt.xlabel('Source')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Convert 'date' to datetime if it's not already
sources_analysis['date'] = pd.to_datetime(sources_analysis['date'])

# Extract year from the date
sources_analysis['year'] = sources_analysis['date'].dt.year

# Count occurrences of each year
year_counts = sources_analysis['year'].value_counts().sort_index()

# Create a bar plot
plt.figure(figsize=(12, 6))
year_counts.plot(kind='bar')

# Customize the plot
plt.title('Distribution of Sources by Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=0)  # No rotation for years
plt.tight_layout()

# Show the plot
plt.show()

# %%
for i in wrong_guesses[:50]:
  decoded_text = distillroberta_nli_tokenizer.decode(x_test['input_ids'][i], skip_special_tokens=True)

  print("Input text:")
  print(decoded_text)
  print("True label:")
  print(y_test.iloc[i])
  print("Predicted label:")
  print(predictions_model.numpy()[i])

  print("-" * 50)
# Out:
# Input text:
# the stage set battle group walmart wmt the unionbacked group walmart expects thousand worker participate protest planned week. employee ask country largest employer end call retaliation speaking better pay, fair schedule affordable health care. such retaliation include shuffling around shifts, cutting hour moving around departments. walmart say protester make handful 1.3 million workforce. in effort stop them, walmart filed complaint last week national labor relation board, claiming united food commercial worker union subsidiary known ourwalmart unlawfully organized picket line demonstration past six months. retailer said action disrupted business, worker ongoing action violate national labor relation act, prohibits picketing period 30 day without filing petition form union. related: suck work black friday representative federal agency currently holding talk walmart headquarters bentonville, arkansas, complaint. nancy cleeland, spokeswoman agency, said email decision agency expected thursday. court wont open day grant injunction thanksgiving holiday, meaning action taken time block planned black friday walkout. cleeland said currently 20 charge filed walmart store individual employee walmart alleging number illegal acts. wouldnt say specific charge are. our walmart, get financial backing support ufcw, say specifically protesting company retaliation employee doesnt specific demand tied black friday walkout. however, 2011, group asked retailer pay worker minimum wage $13 per hour make fulltime job available parttime employee want them. also asked retailer provide affordable health care, predictable hour recognize freedom speech association. walmart would say percentage worker parttime, much paid average. tovar said majority employee fulltime workers, get average hourly wage $12.40, $5 federal minimum wage. jeff landry, employee sapulpa, okla., plan join protest. work 4 9 p.m. attending school day. scheduled shift class, landry complained. say manager responded cutting hour 40 30 week. this meant landry longer eligible health care, since walmart requires worker work average 30 hour per week get benefits. they tried tactic get rid me, said. landry job despite joining walkout last month, protest started walmart los angeles spread store 12 cities. walmart spokesman david tovar said walmart policy prohibits retaliation kind, investigates every allegation. labor law expert say true, employee claim would violate term national labor right act, protects worker kind retaliation. angela cornell, director labor law clinic cornell law school, said walmarts complaint might work labor law prohibit picketing 30 day applies protester trying form union gain collective bargaining rights, employee protesting retaliation. according william
# True label:
# 0
# Predicted label:
# 1
# --------------------------------------------------
# Input text:
# a bullet hole police officer shot seen rear window atatiana jefferson home e. allen ave fort worth, texas, tuesday, oct. 15, 2019. jefferson, black woman, shot white police officer early saturday, oct. 12. (tom fox/the dallas morning news via ap) a bullet hole police officer shot seen rear window atatiana jefferson home e. allen ave fort worth, texas, tuesday, oct. 15, 2019. jefferson, black woman, shot white police officer early saturday, oct. 12. (tom fox/the dallas morning news via ap) fort worth, texas (ap) — furor tuesday killing black woman white fort worth officer became increasingly gun pointed bedroom window. police chief activist said focus wrong gun. officer aaron dean arrested murder charge monday slaying atatiana jefferson. police released arrest warrant tuesday quoting victim’s 8yearold nephew saying jefferson pulled gun hearing suspicious noise behind house. full coverage: shot home black politician others criticized police medium bringing jefferson’s weapon, angrily accusing department trying deflect blame onto innocent victim. the fort worth police department going task providing defense officer,” said lee merritt, attorney jefferson family. interim police chief ed kraus declared absolutely excuse” killing said jefferson behaved texas homeowner would hearing prowler. wasn’t clear warrant whether dean even saw weapon glass. the killing early saturday shocked people across u.s. led many black people wonder whether longer safe police homes. earlier month, white former dallas officer convicted murder sentenced 10 year prison killing black neighbor apartment. said mistook place thought intruder. dean, 34, resigned arrested monday firing single bullet windowpane investigating neighbor’s report front door left open jefferson’s home. jefferson staying late, playing video game nephew. police bodycam video showed dean making way around side house backyard darkness opening fire split second shouting 28yearold jefferson show hands. identify police officer. in arrest warrant, jefferson’s nephew said aunt taken gun purse pointed window. weekend, police department also stirred anger releasing image gun inside home. state rep. harold dutton, black democrat houston, blamed medium part. why would publicize ms. jefferson gun home?” asked. i’m sure police told that. second amendment right
# True label:
# 1
# Predicted label:
# 2
# --------------------------------------------------
# Input text:
# this 2012 presidential race one kind. history crown year debates. and three presidential debate shook race put republican mitt romney back game. the history making element 2012 debate year became interactive social medium event attracting massive audiences. rivaled super bowl wrestlemania audience size lust combat american first time communal experience scoring debate real time. on twitter blog debate scored minute minute grandma, kid everyone else living room. star hollywood medium personalities, politician joined fun folk home. whole nation competed best oneliners, perfect putdown come back debate taking place. trying appear presidential, cagematch mentality sober, thoughtful, reserved approach work social medium world want zinger mock opponent. president obama lost first debate failing satisfy big crowd refusing draw blood. mitt romney similarly lost last debate failing take fight president foreign affairs. the second debate, candidate looking verge fistfight, interrupting calling false claim first true debate new rule era. during debates, twitter gave u much hashtags” big bird, binder bayonets. twitter given birth entirely new debate experience believe new norm presidential debate on. i saw historic shift firsthand four debate sites. genuinely surprised many colleague – honest, solid, hardworking journalist actually watching debate television computer screens. instead, eye perpetually glued ipads, blackberry iphones reading people saying debate twitter feed facebook posts. that instantaneous scoring distorted reality debate journalist surrogate spin room. focus putdowns, oneliners expectation folk tweet dictated said television immediately debates. twitter report 6.5 million tweet tonight final 90 minute presidential debate, 7.2 million tweet second debate new york whopping 10.3 million tweet first debate denver. these metric made first debate tweeted political event sixyear history social networking site. prior that, obama’s dnc acceptance speech charlotte summer mosttweeted political event. twitter created 2006 report 500 million user worldwide. going year’s debate conventional political wisdom political scientist journalist debate don’t really matter. time debate clearly made difference 1960, american saw two major party candidate square television first time history. image sweaty richard nixon five o’clock shadow hurt republican badly. in 13 presidential contest since hard make case presidential debate performance influenced enough voter determine winner presidential election. moments: gerald ford’s mistaken judgment soviet influence poland; george h.w. bush looking watch couldn’t wait get there; al gore’s sighing dismissive regard george w. bush. the power social medium create distorted, avalanche
# True label:
# 0
# Predicted label:
# 2
# --------------------------------------------------
# Input text:
# people purchase firework thursday, july 2, 2020, dublin, calif. many americans, fourth july wont big festivity setting firework themselves. hundred city town canceled show saturday coronavirus pandemic, sale consumer firework booming; though official concerned fire injury pyrotechnic going backyard block parties. (ap photo/ben margot) people purchase firework thursday, july 2, 2020, dublin, calif. many americans, fourth july wont big festivity setting firework themselves. hundred city town canceled show saturday coronavirus pandemic, sale consumer firework booming; though official concerned fire injury pyrotechnic going backyard block parties. (ap photo/ben margot) atlanta (ap) — many americans, fourth july intimate year. also could riskier. saturday unlike independence day recent memory. atlanta san diego, hundred firework show canceled official restrict large gathering coronavirus pandemic, especially infection surge across u.s. with fewer professional celebration, many american bound shoot firework backyard block parties. already : sale booming. public safety official say consumer firework hand mean greater danger injury wildfire part country experiencing dry, scorching weather. advertisement the general public buying ever before,” said steve houser, president national firework association. while it’s clear exactly driving people shops, seller think firework diversion people stuck home pandemic. we’re seeing new customer... usually don’t come firework tents,” said robert fletcher desert sky fireworks, location across arizona. city like los angeles san francisco received complaint illegal firework summer previous years. state allow least type consumer fireworks, many city prohibit them, even nonexplosive sparklers. acknowledge difficult stop people buying outside city limit they’re legal. in arizona, battled wildfire weeks, thousand people signed online petition calling gov. doug ducey ban firework summer. delanie thompson, 28, said started petition seeing neighbor’s house engulfed flame last week wildfire phoenix. said boyfriend forced evacuate home 30 hours. thompson said got angry later saw roadside tent selling firework nearby town. the fourth july independence,” said. fireworks.” authority phoenix suburb glendale seized nearly 4,000 pound banned firework week getting tip illegal sale operation house. advertisement firework big danger many part american west struggle
# True label:
# 1
# Predicted label:
# 0
# --------------------------------------------------
# Input text:
# house intelligence committee chairman adam schiff, dcalif., conduct news conference capitol visitor center transcript phone call president trump ukrainian president volodymyr zelensky wednesday, september 25, 2019. tom williams | cqroll call group | getty image president donald trump monday suggested house intelligence committee chairman adam schiff could face arrest treason recent statement trump call ukraine president. rep. adam schiff illegally made fake & terrible statement, pretended mine important part call ukrainian president, read aloud congress american people, trump tweeted. bore relationship said call. arrest treason? added. neither white house spokesman schiff, dcalif., immediately responded cnbcs request comment president tweet. fiery tweet accusing schiff — leading voice house impeachment inquiry trump — illegally misrepresenting came day president said private staff event used handle spy treason little differently now. he referring source used whistleblower, filed bombshell complaint last month alleging trump using power office solicit interference foreign country 2020 u.s. election asking ukrainian president volodymyr zelensky investigate rumor wrongdoing former vice president joe biden son hunter. call, zelensky suggested ukraine ready buy weapon u.s. military. trump responded, would like u favor though country lot ukraine know lot it. trump appeared referring portion call origin special counsel robert muellers russia probe. suggested would attorney general william barr call people part proposed investigation. reporting complaint, made public last week along memorandum trump july 25 call zelensky, led house speaker nancy pelosi, dcalif., back impeachment inquiry president. dozen democrat came favor inquiry detail call came light. nearly entire house caucus support impeachment inquiry. schiff characterized trump call zelensky classic organized crime shakedown, took analogy contentious hearing thursday acting director national intelligence joseph maguire.
# True label:
# 1
# Predicted label:
# 0
# --------------------------------------------------
# Input text:
# an 86yearold illinois man concealed carry permit fired weapon armed robbery suspect fleeing police last month, stopping man track allowing police make arrest. law enforcement authority described man model citizen” helped others avoid victims” at&t store outside chicago witnessed holdup. man, whose identity withheld press, prevented others entering store theft. police said robber harassed customer pistolwhipped one. since illinois started granting concealed carry permit year, number robbery led arrest chicago declined 20 percent last year, according police department statistics. report burglary motor vehicle theft 20 percent 26 percent, respectively. first quarter, city’s homicide rate 56year low. it isn’t coincidence crime rate started go concealed carry permitted. idea criminal don’t know who’s armed isn’t deterrence effect,” said richard pearson, executive director illinois state rifle association. police department hasn’t changed single tactic — haven’t announced shift policy course — yet incredible numbers.” a july 29 state 83,183 application concealed carry issued 68,549 licenses. end year, mr. pearson estimates, 100,000 illinois citizen packing. illinois began processing request january, gun training shooting class — required application — filling rifle association able schedule them, mr. pearson said. photos: top 10 handgun u.s. the temperature would 40 below, you’d guy range, crack ice gun see target,” mr. pearson said. they’d it, passionate getting license.” the demand slowed summer, mr. pearson expects state issue 300,000 concealed carry permit said done. illinois became 50th state nation issue concealed weapon permits. individual permit cost $600 requires least 16 hour classes. the chicago police department credited better police work reason lower crime rate year. police superintendent garry f. mccarthy noted confiscation 1,300 illegal gun first three month year, better police training intelligent policing strategies.” the chicago police department didn’t respond request comment washington times. however, impact concealed carry can’t dismissed. instead creating crimes, many gun control advocate warn, increased concealed carry rate coincided lower rate crime. a july study crime prevention research center found 11.1 million american permit carry concealed weapons, 147 percent increase 4.5 million seven year ago. meanwhile, homicide violent crime rate dropped 22 percent. there’s lot academic research that’s done this, look
# True label:
# 2
# Predicted label:
# 0
# --------------------------------------------------
# Input text:
# democrat congress seeking capitalize unrest teacher pay led classroom walkout handful states, offering electionyear plan roll back part last year’s gop tax cut boost fund schools, including higher wage educators. state local school district would get $50 billion decade raise teacher pay recruit educators. plan would provide another $50 billion school building resources, expand public school teachers’ collective bargaining rights. the measure among series initiative democrat offering rally core voter ahead election november, every house seat ballot, along third senate seats. minority party chambers, democrat lack power bring plan vote. on monday, democrat focused controversy surrounding president donald trump allegation corruption administration, promising new ethic rule restriction campaign donation undisclosed contributors. to pay education plan, house minority leader nancy pelosi democratic leader want cancel new tax cut benefit wealthiest 1 percent americans. instead giving tax cut richest americans, give pay raise teacher country student depend succeed,” senate majority leader chuck schumer said news conference. joining democrat leader american federation teacher national education association, key donor party candidates. the recent teacher walkout occurred important election battleground state including arizona, gop senator jeff flake retiring, west virginia, incumbent democratic senator joe manchin fighting keep seat. teacher west virginia ended nineday strike march 5 percent pay raise. state teacher demonstrated higher pay include oklahoma, kentucky colorado.
# True label:
# 1
# Predicted label:
# 2
# --------------------------------------------------
# Input text:
# under radar blog archive select date… october, 2019 september, 2019 august, 2019 july, 2019 june, 2019 may, 2019 april, 2019 march, 2019 february, 2019 january, 2019 december, 2018 november, 2018 hillary clinton certifies email handover, aide demur acting response request federal judge, former secretary state hillary clinton friday submitted first official, formal certification penalty perjury workrelated email turned state department. however, two aide clinton appear rebuffed parallel request u.s. district court judge emmet sullivan similarly certify theyd turned certain email record possession relating work state. last week, sullivan ordered state department ask clinton, former chief staff cheryl mill former deputy chief staff huma abedin personally vouch theyd turned record responsive freedom information act request conservative group judicial watch filed seeking information abedins employment arrangements. a court filing justice department submitted friday afternoon (posted here) indicated clinton replied department request submit declaration pursuant court order. however, state spokesman alex gerlach confirmed saturday submission clinton camp arrive friday, wasnt immediately noticed went someone vacation. clinton formal declaration may satisfy critic said directed potential federal record private email account turned former agency, cant personally certify handover complete left actual sorting process attorneys. while sullivan order sought personal confirmation three former official theyd turned related record well detail use mill abedin made clinton email server, neither two aide sent personal declaration court. instead, lawyer staffer submitted letter providing detail situation. clinton decision offer underpenaltyofperjury declaration aide seems reflect divergence legal strategy political exigency. a presidential candidate someone likely provide public testimony soon house panel investigating benghazi attacks, clinton may practical choice testify oath handling emails. meanwhile, aide others caught probe may elect defensive posture, declining make official statement could serve fuel ongoing future investigation benghazi, email arrangement matter mill attorney, beth wilkinson, said letter mill turned workrelated record state june 25 plan provide remainder monday. ms. mill account secretary clinton email server, wilkinson added. abedins lawyers, karen dunn miguel rodriguez, said client produced record state july 9, planning another production saturday expect complete turning workrelated record august 28. abedins attorney also noted state department sent first request record incorrect address also sent followup email dated email addresses. ms. abedin’s initial ability respond impeded department’s failure
# True label:
# 0
# Predicted label:
# 2
# --------------------------------------------------
# Input text:
# president barack obama’s administration reportedly misled congress — american people — crucial element iran nuclear deal. a gopled investigation senate permanent subcommittee investigation revealed wednesday obama’s treasury department secretly worked license allow iran access american financial system. a license, according treasury department, authorization [treasury] engage transaction otherwise would prohibited.” it’s big claim. recall iran deal u lift certain sanction tehran exchange iranian curbing nuclear program. u didn’t remove every penalty signing agreement 2015 — meaning iran’s access u financial system still limited. but according new report, u treasury department issued license oman’s bank muscat february 24, 2016. license would let iran change $5.7 billion worth omani rial held bank euro — first changing u dollars. iran could change money dollar without license, since would violated sanction still place. however, two u bank refused help conversion iranianowned omani rial dollar — even obama official approached — reportedly citing severe hit reputations. all, knew would perceived circumventing iran nuclear deal aiding tehran. the associated press first report senate subcommittee’s findings. sean kane, former sanction official obama’s treasury department lawyer dechert llp, told treasury not practice allowing iran even indirect access u financial system.” he continued, reported appears limited authorization would allowed onetime conversion specific iranian reserve held abroad, something allowed continue accessing u financial system goingforward basis.” kane also noted treasury issue license based america’s changing foreign policy needs. that’s critic see it. obama effort boost iran’s economy ran counter american interests, skirted law,” jonathan schanzer, iran expert conservative foundation defense democracy think tank, tweeted wednesday. did obama administration lie helping iran? what make revelation worse, republican lawmaker say, obama administration may best misled — worst, deliberately lied — granting iran limited access u financial system. the obama administration misled american people congress desperate get deal iran,” sen. rob portman (roh), subcommittee’s chair, said statement. here’s portman others make claim: wednesday’s report, note statement top obama official saying type action wasn’t possibility. iran continue denied access [us’s] financial commercial market,
# True label:
# 0
# Predicted label:
# 2
# --------------------------------------------------
# Input text:
# after year blocked democratic leader harry reid, senate finally get chance next year vote legislation force broad audit federal reserve’s decisionmaking. once championed congress former rep. ron paul, push force country’s central bank undergo full audit picked son, sen. rand paul, others, backing leader new republican majority, sen. mitch mcconnell, kentucky republican, whose office say legislation earn floor vote. but despite overwhelming support house, legislation twice passed, bill sure thing senate, fed pushing back. chairwoman janet l. yellen said earlier month fed remains opposed stricter oversight monetary policy decisions, reuters reported fed official lobbying capitol hill drop audit push. back 1978 congress explicitly passed legislation ensure would gao audit monetary policy decisionmaking, namely policy audits. certainly hope continue, try forcefully make case that’s important,” ms. yellen told reporter press conference two week ago. for supporter congress, fight matter constitutional prerogative good governance. argue president obama’s 2009 recovery act, totaled $800 billion spending tax cuts, dwarfed trillion dollar stimulus federal reserve oversaw. they’ve luck house, legislation calling audit passed twice, including recently september 33392 vote. one republican, half democrat chamber, voted legislation. see also: obama fight lameduck label, chime hotbutton social issue but mr. reid, nevada democrat, refused give bill floor time senate, bottling 2012 2014. norm singleton, vice president policy campaign liberty, ron paul’s political organization, said striking because, 2010, mr. reid seemed throw support behind audit. mr. reid’s side suffered huge loss november’s elections, gop netting nine seat — enough 5446 majority, delivering control floor schedule mr. mcconnell undercutting mr. reid’s power. his refusal bring popular legislation like ‘audit fed‘ floor major reason he’s demoted minority leader,” said mr. singleton, spent year mr. paul’s legislative director house. change senate leadership present u best opportunity yet get standalone vote ‘audit fed.’” still, said aren’t taking anything granted, particularly report fed official quietly lobbying oversight. this popular 75 percent american people, it’s popular among wall street; it’s popular among banks; it
# True label:
# 2
# Predicted label:
# 1
# --------------------------------------------------
# Input text:
# immigration advocates, eagerly awaiting hearing early hint tenor debate immigration unfolds house, said use word amnesty” would likely bad sign favor comprehensive overhaul. representative john conyers jr., democrat michigan, tried set tone early — hope one us term ‘illegal immigrants’ today,” said opening remarks. aword, immigration advocate called amnesty,” came twice. addition mr. bachus, representative trey gowdy, republican south carolina, also used phrase: country’s first foray amnesty.” expressed concern respect rule law.” meanwhile, representative eric cantor virginia, no. 2 house republican, used speech legislative priority beyond fight deficit reduction try soften party’s position immigration. speaking research group downtown, explicitly embraced offering illegal immigrant brought united state child pathway legal residency citizenship, position opposed. endorsed broad term comprehensive overhaul nation’s immigration laws. i’m pleased discussion make border security, employment verification creating workable guest worker program immediate priority. it’s right thing families, security, economy,” mr. cantor said. warned, would rather avoid fixing problem order save political issue.” representative raúl r. labrador, republican idaho, also challenged immigration advocate question political versus policy victory. if want political solution, guy going insist pathway citizenship,” said. you’re going beat republican head issue. want policy solution, think there’s good house representative u come together, actually pas pragmatic solution current problem have, solve modernize immigration system year come.” in flurry immigration legislation offered recent day house, bipartisan group lawmakers, led representative jerrold nadler, democrat new york, introduced bill tuesday would allow american citizen foreignborn samesex spouse partner obtain permanent resident visas, known green cards, them. mr. nadler’s proposal would allow wellestablished samesex couple apply green card, avoiding direct challenge federal law ban recognition gay marriage.
# True label:
# 0
# Predicted label:
# 2
# --------------------------------------------------
# Input text:
# with supreme court expected rule day whether state samesex marriage ban constitutional, hillary clinton become one country prominent politician favor marriage equality. every loving couple & family deserves recognized & treated equally law across nation. #lovemustwin #lovecantwait –h — hillary clinton (@hillaryclinton) april 28, 2015 but clinton prominent support samesex marriage right part sharp shift issue past year — transformation has, many ways, mirrored american whole went time span. during 2008 campaign, clinton opposed federal samesex marriage rights, saying issue left states. take 2016 campaign, shes complete support. it pivot struggled explain, including june told nprs terry gross, think youre trying say that, know, used opposed, im favor, political reason — thats flat wrong. it easy imagine clinton, like politicians, made calculated political decision flipflop. political environment far friendlier lgbt right decade ago, all. clinton, who 67 year old, would similar million american age group changed mind nonpolitical reasons. support samesex marriage nearly tripled among american around clinton age 1996 2014, according gallup surveys. so even though clinton might find predicament — supporting policy — case samesex marriage, attitude changing belief mirror publics. there charitable version clinton evolution look lot like american public, come see issue differently genuinely evolved. i think american — lgbt —appreciate journey many folk taken issue marriage, jason rahlan, spokesperson human right campaign (hrc), also worked clinton state department 2008 campaign, told email. many seen within families. hillary clinton evolution match national trend even way clinton talk issue similar americans. clinton insists genuinely evolved stance — phrase president barack obama also used describe thought samesex marriage. clinton explained it, didnt grow thinking possibility samesex marriages, shifted position advocate pushed issue public spotlight forced give thought. just youre politician, doesnt mean youre thinking human being, clinton told nprs gross. gather information, think positions, youre 100 percent set … youre constantly reevaluating stand. true me. the final reevaluation came clinton officially announced support samesex marriage 2013. clinton relationship lgbt advocate always somewhat tense, least president bill clinton approved defense marriage act, effectively banned samesex marriage federal level supreme court struck part law 2013. but lgbt advocate quickly fell behind clinton announced support marriage equality.
# True label:
# 0
# Predicted label:
# 2
# --------------------------------------------------
# Input text:
# republican member senate judiciary committee tuesday strongly criticized attorney general eric h. holder jr.’s recent decision appoint two united state attorney investigate recent disclosure classified national security information, saying move enough appoint special prosecutor. at committee hearing, republican senator — led senator lindsey graham south carolina — accused administration leaking information said mr. holder trying shield obama administration scrutiny prosecutor would completely independent justice department. mr. graham said excerpt recently published new york time book confront conceal,” david sanger, time correspondent, cyberattacks united state iran revealed clearly people around president leaking story involve highly classified information.” the concern you’ve got one program ‘fast furious’ embarrassment administration it’s like pulling teeth get information ‘fast furious, when, ” said, referring operation fast furious, bungled guntrafficking case. but program national security front seem show president strong leader, read paper. concern think lot u believe ever need outside special council, now. say?” mr. holder said two united state attorney appointed — ronald c. machen, united state attorney district columbia, rod j. rosenstein, counterpart maryland — exemplary prosecutor like federal authority freedom pursue evidence wherever may lead. i think missing something here,” mr. holder said, interrupted mr. graham. i think missing something here,” mr. graham said stern tone. think missing fact big deal, handling way creates suspicion be. and, i’m asking find lawyer country could say — virtually u — could say right person job rather picking two people telling u great are. don’t know people adam’s house cat.” senator john cornyn, republican texas, particularly critical mr. holder called resign handling fast furious,” leak investigation lack leadership. mr. holder said would resign. earlier hearing, mr. holder said willing make compromises” member congress information subpoenaed fast furious.” mr. holder said compromise would avoid impending constitutional crisis” house oversight committee vote june 20 recommend full house hold mr. holder contempt.
# True label:
# 0
# Predicted label:
# 2
# --------------------------------------------------
# Input text:
# the americanordered drone strike killed one iran’s powerful military leaders, qassem soleimani, triggered retaliation iran put american troop middle east heightened alert. also brought foreign policy top news cycle. event unfold uncertain, leave analysis others expertise world affairs. instead, we’d like take step back use political science polling data explore question heightened tension iran could affect 2020 primary general elections. first, political science research found foreign policy doesn’t significantly affect people’s votes. isn’t always case. example, foreign policy impact it’s big part national conversation two party clearly contrasting position — two condition iran episode could meet. we don’t actually know much role international affair play primaries, though, it’s rare primary candidate experienced foreign policy. year, candidate former vice president joe biden. two recent poll say democratic primary voter trust foreign policy. according cnn, nearly half (48 percent) democrat democratic leaner said thought biden could best handle foreign policy; sen. bernie sander came second place 14 percent. poll taken immediately strike killed soleimani, huffpost/yougov found 62 percent democrat democratic leaner trust biden iran, although sander sen. elizabeth warren weren’t far behind, 47 percent trusting (respondents allowed select multiple candidate trusted). but even initial setup chessboard privilege biden, candidate move issue could also determinative. someone like sanders, critical biden’s vote go war iraq, could seize upper hand primary becomes question antiwar. voter likely listening closely candidate say iran next week’s debate, could makeorbreak moment many candidates, one theory foreign policy affect primary serf litmus test serious candidate must pass. take 2016 republican primaries, ben carson may flunked test when, coordinated terrorist attack paris november 2015, struggled articulate would combat terrorism. even adviser said publicly unprepared issue. although it’s impossible know exactly much hurt carson voters’ eyes, running even nowpresident trump poll time attacks, sharply declined thereafter ceased serious threat nomination. extreme example aside, though, iran’s effect primary might fleeting. news cycle move on, past event touted game changers” failed permanently change state race. remember polling bump biden (or anyone else) get week could wear quickly, especially conflict defuses. for iran real effect general election, would likely stay news next several months. even then
# True label:
# 1
# Predicted label:
# 0
# --------------------------------------------------
# Input text:
# this making round quite bit weekend, including reader talking article earlier today. quite people seem concerned (fair enough) outright confused (including truly) situation dzhokhar tsarnaev read miranda right questioned. a pointed earlier, apparently exception granted miranda public safety stake. it’s rather ambiguous term decide safety public clearly danger degree sufficient invoke exception. one protest laid fairly clearly. quoting joyner: i problem principle exigent circumstance exception miranda. envision situation police simply don’t time particular nicety public truly imminent danger. this, however, seem one situations. particular sympathy tsarnaev, given sanctuary country allowed escape wartorn homeland much better life to, allegedly, terrorize city called home, murdering maiming innocents. there’s theory case i’m aware public continued danger. i’m afraid disagree dr. joyner one, least point. you’ve got two suspect (one dead) seen leaving later throwing bomb left explosive apartment, possibility nasty surprise waiting certainly seems viable. questioning remaining suspect look like fair game me. but larger part question seems confusion precisely sort rights” we’re talking here. apparently nothing sacred reading someone miranda right unless plan using statement court anyway. doug mataconis explains. before getting discussion public safety” exception, it’s important recognize miranda require, consequence police comply properly. contrary conclusion people likely gather watching crime drama like law & order, officer required give warning arrest someone failure give warning result dismissal case. miranda properly seen evidentiary rule government must follow wish interrogate suspect eventual defendant use whatever statement interrogation elicits court. suspect given miranda warning state attempt utilize postarrest statement him, government generally barred using statement court. orin kerr notes, however, supreme court ruled chavez v. martinez, 538 u.s. 760 (2003) police may arrest defendant, fail read rights, interrogate him, obtain statement long don’t use statement court. additionally, court held evidence police discover result statement used court defendant, radically different 4th amendment’s fruit poisonous tree” doctrine provides evidence obtained result illegal search, even indirectly, inadmissble unless exception applies. it seems big takeaway relate fear expressed tsarnaev might simply let attorney filed protest questioning without miranda right read. doesn’t legally right read avenue demand release lack it. possible downside statement might allowed evidence court. public safety exception could allow used anyway, providing don’t hold question long without taking step
# True label:
# 2
# Predicted label:
# 0
# --------------------------------------------------
# Input text:
# a mr. coates testified congress one year ago, real question reparation whether we’ll tied somethings past, whether courageous enough tied whole them.” finding consensus black reparation challenging. varying survey poll suggest american may ready address grievance black people america, may ready redress grievances. discussion taken place 100 years, union army gen. william sherman 1865 tanehisi coates today. that angst yielded surge support idea black life matter politician corporations. whether it’s regarding police populace, many black folk looking one thing – real conviction. rising call policy reflects profession concern black people – cases, call black reparations. george floyd’s death month ago hand minneapolis police upended country – yielding social unrest, public uprisings, renewed political urgency. angst manifested promise police reform, rebuke removal racist edifices, stunning declaration corporation – black life matter. with said, concern change viewpoint expressed corporation politician performative. let’s turn black life matter black life marketing,” challenged recent commentary black enterprise. urged corporation look beyond public declaration examine diversity hiring, among practices. whether it’s regarding police populace, many black folk looking one thing – real conviction. rising call policy reflects profession concern black people – cases, call black reparations. finding consensus black reparation challenging. varying survey poll suggest american may ready address grievance black people america, may ready redress grievances. discussion taken place 100 years. iconic, albeit, slightly inaccurate phrase accompanies idea black reparation – 40 acre mule.” phrase derived special field order no. 15, military order issued union army gen. william sherman 1865 affected georgia, south carolina, florida coasts. first article reads: the island charleston, south, abandoned rice field along river thirty mile back sea, country bordering st. john river, florida, reserved set apart settlement negro made free act war proclamation president united states. after second article emphasized military protection negro free,” designation regarding 40 acres” made third article: whenever three respectable negroes, head families, shall desire settle land, shall selected purpose island locality clearly defined, within limit designated, inspector settlement plantation himself, subordinate officer may appoint, give license settle island district, afford assistance enable establish peaceable agricultural settlement. three party named subdivide land, supervision inspector, among others may choose settle near them, family shall plot (40) forty acre tillable ground, border water channel, 800 foot water front
# True label:
# 1
# Predicted label:
# 2
# --------------------------------------------------
# Input text:
# iraqi prime minister nouri almaliki threw country political system crisis sunday, announced would staying prime minister deadline form new government expired without agreement 12 baghdad time. maliki announced plan sue iraq president, fuad masum, violating country constitution, totally unclear when, ever, iraq return normal democratic procedures. all underscore why, saturday press conference u intervention iraq, president obama emphasized need iraqi political reform solve isi crisis. ultimately, there going american military solution problem, president obama told reporters. there going to iraqi solution. key line understand want grasp administration approach iraq — goal u military campaign narrow might think. the american objective obamas airstrikes iraq clear, limited. american airpower protect iraqi kurdistan advance militant islamic state (isis), attempt break isi siege thats starving 40,000 member yazidi minority isolated mountain. so u stopping there? isi control huge swath land size belgium iraq syria. group pose serious threat iraqi government possibly even stability entire region. united state beat isi back kurdistan, elsewhere? that line iraqi solution administration answer. fact, obama administration consistent question since june, isi first took control big chunk iraq. see isi as, heart, political problem — one cant solved solely force. march kurdistan siege sinjar narrow military problems, thus merit military solutions. distinction military political problem heart obama administration thinking iraq. isi political problem military problem isi isnt terrorist group rampaging iraq (though definitely that). many way expression sunni muslim minority anger shiadominated government. sunni minority iraq, based mostly country northern half, seen political power decline since 2003 usled invasion toppled sunni government, mostly shia. the sunni lot different grievances, kirk sowell, political risk analyst expert iraqi politics, says. current government fault. prime minister maliki treated sunni badly, including forcibly breaking peaceful protest movement 2013. seemingly authoritarian turn sunday show far maliki remains moving towards inclusive style governance. some sunni grievance get fundamental issue within iraqi state itself, beyond even better government could easily fix. even maliki werent power, sunni grievance shia government would problem [trying resolve], sowell says. includes widespread, false, belief among sunni theyre actual demographic majority, entitled political power iraqi politics. no amount military force solve iraq
# True label:
# 0
# Predicted label:
# 1
# --------------------------------------------------
# Input text:
# president donald trump sure sound like he’s thinking pardoning paul manafort. in interview fox & friends’ ainsley earhardt thursday morning responded key question — pardon former campaign chair, convicted eight count federal crime tuesday? — arguing, essence, prosecution probably politically motivated. justice department, said, seems like go lot republicans.” here’s trump said asked directly he’d pardon manafort: i great respect done term gone through. know worked ronald reagan years. worked bob dole. guess firm worked mccain. worked many, many people, many, many years. would say did, charge threw him, every consultant, every lobbyist washington probably does. president @realdonaldtrump would pardon paul manafort pic.twitter.com/98qpg8aaua — fox & friend (@foxandfriends) august 23, 2018 he claimed hillary clinton’s campaign done worse manafort didn’t face consequences, evidence disparity. called podesta group, specifically, came scrutiny special counsel robert mueller’s probe. if look hillary clinton’s person, take look people work hillary clinton, mean, look crime clinton did. email deletes 33,000 email get subpoena congress, justice department nothing it? crime done. — look podesta. podesta supposed manafort steroids. made close firm. going indicted next day, heard. never happened. instead, go manafort. trump didn’t get argument conservative made political context prosecution manafort michael cohen, trump’s longtime fixer also pled guilty eight count federal crime tuesday: justice department wouldn’t normally bothered take case without interest trump. mueller would like two men cooperate trump investigation, conviction carry jail time could offer incentive men turn. trump say respected manafort going trial rather flipping. trump’s play along discredit justice department trump nothing praise manafort interview. it’s striking say manafort — convicted felon — compared say justice department. implied outright said several time interview justice department filled democrat biased republicans. if look president obama, massive campaign violation,” trump said. (obama’s campaign paid fine civil, criminal offense.) different attorney general viewed lot differently. somebody seem like go lot republicans.” later, made point again: dems strong justice department,” trump told earhardt. put attorney general never took control
# True label:
# 0
# Predicted label:
# 2
# --------------------------------------------------
# Input text:
# ethic expert astonished trump acknowledges repaid cohen via retainer ‘nothing campaign’ donald trump admitted $130,000 hush money paid pornographic film actor stormy daniel stop going public alleged affair him, despite president previously denying knowledge deal. the revelation threatened engulf trump one tawdry legally damaging scandal presidency, thursday provoked astonished reaction ethic experts. donald trump repaid lawyer stormy daniel hush money, say rudy giuliani read more daniels’ lawyer called revelation stunning” said: sex … coverup.” rudy giuliani, former mayor new york one trump’s lawyers, revealed wednesday night trump reimbursed personal lawyer, michael cohen, $130,000 paid daniels. a report emerged thursday nbc cohen’s phone subject federal wiretap least one call cohen white house intercepted. white house press secretary, sarah sanders, afternoon briefing shortly afterwards declined comment report. referred reporter trump’s outside lawyer department justice. however nbc later corrected report saying cohen’s call monitored via pen register, simply track call involve conversation recorded. daniels, whose real name stephanie clifford, claim sexual encounter trump 2006 – month wife, melania, gave birth – paid stay silent part nondisclosure agreement seeking invalidate. trump told reporter air force one last month know $130,000 payment daniel – made cohen day 2016 presidential election – source money. but giuliani said live television wednesday trump indeed reimbursed cohen payment, president reversed position extraordinary sequence tweet – hour leading national day prayer white house. at 6.46am thursday, trump wrote twitter, uncharacteristically legalminded language, cohen received monthly retainer. campaign nothing campaign, entered into, reimbursement,” nondisclosure agreement daniels. claimed: agreement … common among celebrity people wealth.” trump described allegation affair false extortionist”, adding: money campaign, campaign contributions, played roll [sic] transaction.” donald j. trump (@realdonaldtrump) mr. cohen, attorney, received monthly retainer, campaign nothing campaign, entered into, reimbursement, private contract two parties, known nondisclosure agreement, nda. agreement are..... sander said trump’s comment air force one: didn’t know time eventually learned” payment made. added president denies continues deny” allegation affair conceded learned
# True label:
# 0
# Predicted label:
# 2
# --------------------------------------------------
# Input text:
# ...
# True label:
# 1
# Predicted label:
# 0
# --------------------------------------------------
# Input text:
# after cardin rejected measure, called mcconnells move pas funding political stunt. pushed provision including money small business administration disaster assistance grant people already banking relationship receive aid. speaking senate floor, mcconnell said talking changing policy language party negotiated last month part unprecedented $2 trillion emergency spending package. urged democrat block emergency aid even oppose want something — tweak small business aid program emergency funding hospital states, proposal democratic leader outlined wednesday. with senator capitol, senate majority leader mitch mcconnell tried approve measure unanimous vote. sen. ben cardin, dmd., objected request, stalling legislation. senate democrat thursday blocked republican push unanimously pas bill put $250 billion loan program small business devastated coronavirus pandemic. u.s. senate majority leader mitch mcconnell (rky) leaf night day effort wrap work coronavirus economic aid legislation prevent spread coronavirus disease (covid19) washington, u.s., march 21, 2020. sen. chris van hollen, dmd., tried unanimously pas democratic amendment. mcconnell blocked it, senate adjourned monday roughly 30minute pro forma session. also see: coronavirus development thursday. it unclear republican democrat try reach agreement emergency legislation pas coming days. house speaker nancy pelosi indicated could try pas democratic bill friday — republican likely block representative washington. speaking reporter thursday, pelosi said treasury secretary steven mnuchin called tuesday asked quarter trillion dollar 48 hours, data justify needed. echoed cardin calling mcconnells move stunt. let negotiate timing, amount rest, pelosi said emergency aid. the kentucky republican said thursday small business aid part $2 trillion rescue law risk exhausting funding right now. the trump administration cited strong demand loan week asked congress money program, designed help small business keep employee payroll. lawmaker initially approved $350 billion loans. forgiven partly fully company use expense payroll, rent utilities. on wednesday, pelosi senate minority leader chuck schumer asked emergency bill include $250 billion hospitals, health systems, state local government food assistance programs, top money small companies. however, pelosi said wanted $125 billion existing program specifically, another $125 billion communitybased lender sba disaster assistance loan grants. the democrat said wanted bill separate another package hope pas extend major provision $2 trillion emergency measure, direct payment individuals, enhanced unemployment insurance state grants. after small business loan program started friday, report emerged confusion around applications, loan term
# True label:
# 1
# Predicted label:
# 2
# --------------------------------------------------
# Input text:
# while american say freezes” iranian program roll back, fact element frozen, rollback initial agreement relatively minor. example, iran would continue adding stockpile lowenriched uranium, meaning uranium enriched reactor grade, le 5 percent purity. united state maintains detail agreement cannot yet disclose, overall size iran’s stockpile would increase. the reason appears iran would agree convert mediumenriched uranium — fuel enriched 20 percent purity, near bomb grade — oxide form way becoming reactor fuel. process easily reversed, note olli heinonen, former chief inspector international atomic energy agency. mr. netanyahu’s camp israeli analyst say israeli leader’s unstinting opposition substantive political. truly belief deal lifting sanction without fully halting enrichment dismantling centrifuge terrible mistake. also staked premiership fighting iranian nuclear threat, change approach closest ally leaf bit rudderless. the situation changed everybody else except israel understands deal mean flexible,” said giora eiland, senior research fellow institute national security study tel aviv. netanyahu speaks good deal. american speaking reasonable deal, better deal all.” for part, mr. kerry questioned publicly whether mr. netanyahu aware detail agreement. cases, israeli official appear distorted iran would get return. at briefing international journalist wednesday, yuval steinitz, israel’s minister strategic affairs, said deal would directly erase $15 billion $20 billion estimated $100 billion current sanction costing iran annually, lead relief $40 billion indirect effects. state department immediately debunked numbers, noting sanction relief would six months, year. american put figure $10 billion. israeli leader continued cite higher estimates. there also different account would happen heavywater nuclear reactor construction near town arak. facility critical iran’s plan because, operating, could provide steady supply plutonium, fuel north korea pakistan used arsenals. france stepped negotiation 10 day ago complaining draft accord would allow iran get close able insert fuel reactor — point could bombed israel without risking radioactive, environmental disaster. proposed agreement since modified, american official say, make sure iran month year able put fuel reactor.
# True label:
# 0
# Predicted label:
# 2
# --------------------------------------------------
# Input text:
# on sunday, kind news one want see slid across landscape. shooting church white settlement outside fort worth, casualties. delved details, admit feeling first sense relief loss life larger — two innocent life lost along assailant — sense gratitude. our gratitude, also felt gov. greg abbott, come knowledge mass shooter would likely incurred lot mayhem except fact good man volunteer member church’s security team immediately shot back. response era mass shooting in, texas specifically enacted law allow lawabiding citizen carry concealed weapon church (and elsewhere, unless specifically prohibited location). law saved life weekend north texas. regardless whether people like fact, remains true least two church shooting texas recent year ended lawabiding citizen mean willingness fight back. second occurred two year ago sutherland springs, unfortunately resulted loss many lives. recent shooting, incident assailant survive good men responded force. the truth isn’t one solution bring end mass attacks, one reason we’ve supported thing creating federal center evaluate local, state federal law find crack violent criminal exploit obtain firearms. also true part set solution involve enabling innocent people protect including fighting back. if that’s tough consider, another hard reality cast sharp relief latest shooting. many incident — whether it’s knifewielding attacker jewish community new york synagogue, church, mosque shooting — attack north texas assault community, group people freely associating working toward common purpose. these attack pernicious act particular purpose destroy communities. seek kill individual lives. seek kill social bond bind u together. seek divide isolate, leave survivor feeling alone unsafe common space. important u stand together defense hateful, divisive evil purpose. civil society that’s attack.
# True label:
# 1
# Predicted label:
# 0
# --------------------------------------------------
# Input text:
# despite looming criminal investigation, former deputy fbi director andrew mccabe quietly shopping book. the daily beast confirm past several weeks, mccabe rep calling meeting publisher discus printing book telling side story amid yearlong dispute president trump. potential deal first reported new york times. although time reported mccabe received offer multiple publisher reached agreement one, two publishing industry source told daily beast book’s future could potentially complicated possible criminal probe. the u.s. department justice thursday referred mccabe u.s. attorney possible criminal charge related inspector general’s finding repeatedly misled” investigator fbi leak bureau’s probe clinton foundation. but mccabe proceed book, he’ll plenty source material work with. like former boss, ousted fbi director james comey, mccabe took copious note interaction trump, publicly accused exdeputy political bias covering alleged internal corruption. the agreement would come heel slew successful controversial political book 2016 election massive repercussions. comey’s book higher loyalty, hillary clinton’s book happened, former dnc chair donna brazile’s book hack rocketed new york times’ bestseller list past year. and given potentially conflicting account mccabe’s conduct, book former fbi deputy could pit account former bos comey. during interview cnn thursday, comey said could become witness criminal case mccabe. given ig report reflects interaction andy mccabe senior executives, could well witness,” exdirector said. in tweet interview, trump seemed relish conflict two former top officials. james comey threw andrew mccabe ‘under bus.’ inspector general’s report mccabe disaster them! getting little (lot) medicine?” wrote.
# True label:
# 0
# Predicted label:
# 2
# --------------------------------------------------
# Input text:
# a former austin police officer pleaded guilty killing girlfriend unborn child refused abort pregnancy. vontrey clark sentenced life prison capital murder 2015 death girlfriend, samantha dean, sevenmonths pregnant child time, nbc affiliate kxan reports. clark reversed initial guilty plea guilty court monday (dec. 16), month highprofile murder case set go trial. related: exnfl player rae carruth, hired hitman shoot pregnant girlfriend, released prison a part plea agreement, clark sentenced life prison without parole. prosecutor seeking death penalty, austin americanstatesman reports. dean 29 year old time murder. her body found three gunshot wound behind vacant office building bastrop county, texas, austin americanstatesman reports. clark family another woman. onandoff relationship dean seven years, investigator said, demanded get abortion learned pregnancy. when dean refused, clark hired two men kill $5,000, austin americanstatesman reports. investigator discovered dean’s journal south austin home search clue leading killer found entry describing fear life clark going kill her.” dean employee kyle police department victim service unit time death, kxan reports. related: bronx man confesses murdering 21yearold girlfriend in july 2015, clark fired austin police department fled bali, indonesia, without permission leave travis county. his attorney said time seeking medical attention undisclosed ailment, austin americanstatesman reports. a month later, clark extradited back united state federal agents. detained bastrop county jail indicted capital murder charge october eight month dean’s body found, austin americanstatesman reports. you stole favorite person, someone lucky enough know 21 half years. always one biggest cheerleaders,” dean’s sister, taylor alexander dean, said court monday (dec. 16) directly clark, kxan reports. comedian, person always laugh make smile. stole innocent child. stole niece — madeline cherished — valued moment could sit read wanting feel kick.”
# True label:
# 0
# Predicted label:
# 2
# --------------------------------------------------
# Input text:
# the investigation benghazi attack ploy damage hillary clinton possible 2016 presidential candidate, leading republican said sunday. hillary clinton target, house oversight government reform committee chairman darrell issa, rcalif., said nbcs meet press. president obama target. issa, whose panel probing sept. 11, 2012, assault diplomatic outpost left four american dead, said interagency process modifying talking point wake attack scrubbed fact incident terrorist attack getgo. the american people effectively lied period month, charged. thats important get right. issa charged sunday u.s. ambassador thomas pickering led independent review attack behalf state department refused testify hearing last week. pickering flatly denied unwilling appear. i said day hearing willing appear, come hearing [issa] excluded from, pickering told nbcs david gregory. told majority said welcome hearing; could come time. issa said unaware pickerings late notice added private deposition intends formally request monday ambassador appropriate way begin inquiry. fact dont want sort stage show, issa said. republican relentless questioning administration response attack, leaked document revealing last week official state department suggested edits talking point erased reference terrorist groups. while hillary clinton stated publicly involved editing process, criticism former secretary state muchdiscussed possible presidential candidate strong subtext benghazi debate. senate intelligence committee chairwoman dianne feinstein, dcalif., said meet press” issas panel deliberately put clinton ambition crosshairs. my concern hillary clinton name mentioned 32 time hearing, point hearing discredit secretary state, high popularity may well candidate president, feinstein said. meanwhile, national republican congressional committee using benghazi issue raise money, washington post reported. going obama benghazi. help u fight now,” proclaims page nrcc site. on new fundraising page, committee asks donation keep fight, declaring coverup” using picture obama clinton. the page implores supporter demand answers.” on cbc’s face nation” sunday, former secretary defense robert gate forcefully defended obama administration’s action benghazi, saying critic cartoonish impression military capability military forces. gates, republican holdover bush administration stayed two year obamas first term, repeatedly declined criticize policymakers responded attack left four american dead, including ambassador chris stevens. frankly, job time, think decision would were, said gates, chancellor college william mary virginia. we dont ready force standing middle east, getting somebody timely
# True label:
# 1
# Predicted label:
# 2
# --------------------------------------------------

# %%
sources_analysis.to_csv('distill_roberta_fine_tuning_wrong guess(7.21.24).csv', index=False)
