# %%
# %%capture
# !pip install tensorflow-datasets==4.8 --quiet
# !pip install tensorflow==2.15.0 --quiet #15 13
# !pip install tf_keras==2.15.0 --quiet
# !pip install tensorflow-text==2.15.0 --quiet #15
# !pip install pydot --quiet
# !pip install transformers==4.17 --quiet
# !pip install -U scikit-learn

# %%
#Tensorflow libiries
from tensorflow import keras
from tensorflow.keras.layers import Embedding, Input, Dense, Lambda
from tensorflow.keras.models import Model
import tensorflow as tf
import tensorflow.keras.backend as K
import tensorflow_datasets as tfds

#Transformers - BERT from huggingface
from transformers import BertTokenizer, TFBertModel
from transformers import logging
logging.set_verbosity_error()
from transformers import AutoConfig
from tensorflow.keras.callbacks import EarlyStopping

#NLP libiries
import sklearn as sk
from sklearn.metrics import classification_report
import os
import nltk
from nltk.data import find

#data process
import re
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import multiprocessing
import pandas as pd
import math
from bs4 import BeautifulSoup
import os
import json

# %%
#loading the pre-trained tokenizer and model
bert_tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
bert_model = TFBertModel.from_pretrained('bert-base-uncased')
# Out:
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/511M [00:00<?, ?B/s]

# %%
#load the dataset with error handling
try:
    train_df = pd.read_csv('balanced_train_data(Revised)-2.csv')
except pd.errors.ParserError as e:
    print(f"Error reading CSV: {e}")
    # Print the lines around the problematic row
    with open('full_train_data(Revised).csv', 'r') as f:
        lines = f.readlines()
        for i in range(17622, 17626):
            if i < len(lines):
                print(lines[i])

test_df = pd.read_csv('balanced_test_data(Revised)-2.csv')

# Adjust pandas display settings to show all rows and columns
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_colwidth', None)  # Show full content of each column
pd.set_option('display.width', None)  # Auto-detect width of the display

# %%
train_df.head(1)
# Out:
#                                           title        date  \
# 0  want shrink wage gap? help parent care kids.  2016-04-12
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0  norway may seem like odd subject equal pay day united states. people, exactly subject help kickstart move reduce stubborn income gap men women. in early 1990s, norway tried something first europe: four week mandatory paternity leave workers. addition changing country’s cultural attitude toward childrearing (fathers taking several month care child commonplace) now10 week daddy leave” economic side effect well. country’s gender wage gap shrunk half. in 1991, working woman norway made 20 percent le men, according data organization economic cooperation development (oecd). 2010, 8.3 percent. holding policy norway panacea social issue u problematic. norway smaller, socially progressive (with heavily subsidized national daycare system), centralized government. u observes equal pay day april 12, advocate gender equality public private realm giving credence idea supporting woman home inextricably linked supporting workplace. specifically, they’re making case investment child care could help shrink pay gap – added bonus growing economy. according analysis leftleaning economic policy institute released earlier month, access affordable child care would help increase participation woman labor force, thereby growing economy estimated $210 billion year. the gender wage gap definitely driven part wage penalty faced woman likely extended period workforce caring sick relatives,” josh bivens, research policy director epi, writes via email. giving parent greater access highquality, affordable child care early childhood education, make easier want work participate labor force…. increase size labor force, turn boost gdp.” some business business group agree. subsidized child care encourage lowskilled parent maintain connection labor force upgrade skill education, thereby contributing economic growth productivity longer term,” read 2015 analysis state childcare cost committee economic development, nonprofit businessled public policy organization arlington, va. recommends expanding certain childcare credit worker employers. equal pay day united state observed every year day woman catch financially annual pay male counterparts. year’s observance fall april 12, meaning took american woman one year 103 day earn american men earned 2015. the day got plenty political attention, too. president obama dedicated monument women’s equality tuesday, hillary clinton took part panel pay transparency included megan rapinoe, one u women’s soccer star filed complaint equal employment opportunity commission u soccer federation unfair pay practice last month. per census bureau data, woman american workforce make 79 cent every dollar white man makes, it’s worse woman color (60 cent black women; 55 cent latino women). shortfall cost american woman combined $500 billion annually, according report released tuesday national partnership woman & families. if gap eliminated, average, working woman united state would enough money approximately: 83 week food family; seven month mortgage utility payments; 11 month rent; nine year birth control,” report reads. the wage disparity men woman barely changed past two decades, say national partnership vice president vicki shabo. 2006, woman made 77 cent every dollar earned white males, says. on family leave, least, small promising movement several fronts. january poll found 80 percent likely voters, including 94 percent democrats, 80 percent independents, 65 percent republican characterized thing like equal pay, paid time off, affordable child care good nation. issue become talking point presidential candidate politician side aisle. three states, rhode island, california, new york, well city like washington, d.c., san francisco, introduced paidleave rules. major tech companies, twitter netflix etsy, recent month falling introduce increasingly competitive inclusive paidleave allowance employees. there still obstacles, ms. shabo says. 13 percent u worker access paid leave all, look state population need, taken action, there’s pretty sub ...
#
#    bias bias_text                     source
# 0     1    center  Christian Science Monitor

# %%
print(f"basic train_df info: ",train_df.shape)
# Out:
# basic train_df info:  (7740, 6)

# %%
test_df.head(1)

# %%
print(f"basic test_df info: ",test_df.shape)
# Out:
# basic test_df info:  (3318, 6)

# %%
# extract the train and test text from both dataframes
train_text = train_df['content_original']
train_text_labels = train_df['bias']

validate_text = test_df['content_original'][0:1105]
validate_text_labels = test_df['bias'][0:1105]

test_text = test_df['content_original'][1105:]
test_text_labels = test_df['bias'][1105:]


print(f"size of training dataset: ",len(train_text))
print()
print(f"size of valid dataset: ",len(validate_text))
print()
print(f"size of testing dataset: ",len(test_text))
print()
print(f"Left with Label 0 ")
print(f"Center with Label 1 ")
print(f"Right with Label 2 ")
# Out:
# size of training dataset:  7740
#
# size of valid dataset:  1105
#
# size of testing dataset:  2213
#
# Left with Label 0
# Center with Label 1
# Right with Label 2

# %%
MAX_SEQUENCE_LENGTH = 512

# %%
# tokenize the dataset, truncate at `max_length`,

#tokenizing the train text
x_train = bert_tokenizer(train_text.tolist(),
              max_length=MAX_SEQUENCE_LENGTH,
              truncation=True,
              padding='max_length',
              return_tensors='tf')
y_train = train_text_labels

#tokenizing the validate text
x_validate = bert_tokenizer(validate_text.tolist(),
              max_length=MAX_SEQUENCE_LENGTH,
              truncation=True,
              padding='max_length',
              return_tensors='tf')
y_validate = validate_text_labels


#tokenizing the test text
x_test = bert_tokenizer(test_text.tolist(),
              max_length=MAX_SEQUENCE_LENGTH,
              truncation=True,
              padding='max_length',
              return_tensors='tf')
y_test = test_text_labels

# %%
#BERT base uncased model configurations
config = AutoConfig.from_pretrained('bert-base-uncased')

config
# Out:
# BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.17.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }

# %% [markdown]
# #BERT Uncase Model Fine-Tuning

# %%
def create_bert_classification_model(bert_model,
                                      num_train_layers=0,
                                      num_classes=3,
                                      num_filters=100,
                                      kernel_sizes=[3, 4, 5],
                                      hidden_size=768,
                                      dropout=0.1,
                                      attention_probs_dropout_prob=0.1,
                                      hidden_dropout_prob=0.1,
                                      learning_rate=0.00005):

    """
    Build a simple classification model with BERT. Use the Pooler Output for classification purposes
    """
    if num_train_layers == 0:
        # Freeze all layers of pre-trained BERT model
        bert_model.trainable = False

    elif num_train_layers == 12:
        # Train all layers of the BERT model
        bert_model.trainable = True

    else:
        # Restrict training to the num_train_layers outer transformer layers
        retrain_layers = []

        for retrain_layer_number in range(num_train_layers):

            layer_code = '_' + str(11 - retrain_layer_number)
            retrain_layers.append(layer_code)


        print('retrain layers: ', retrain_layers)

        for w in bert_model.weights:
            if not any([x in w.name for x in retrain_layers]):
                #print('freezing: ', w)
                w._trainable = False

    input_ids = tf.keras.layers.Input(shape=(MAX_SEQUENCE_LENGTH,), dtype=tf.int64, name='input_ids_layer')
    token_type_ids = tf.keras.layers.Input(shape=(MAX_SEQUENCE_LENGTH,), dtype=tf.int64, name='token_type_ids_layer')
    attention_mask = tf.keras.layers.Input(shape=(MAX_SEQUENCE_LENGTH,), dtype=tf.int64, name='attention_mask_layer')

    bert_inputs = {'input_ids': input_ids, 'token_type_ids': token_type_ids, 'attention_mask': attention_mask}
    bert_out = bert_model(bert_inputs)

    # Use the last hidden state (contextualized embeddings)
    sequence_output = bert_out[0]

    # CNN layers
    conv_layers = []
    for kernel_size in kernel_sizes:
        conv = tf.keras.layers.Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')(sequence_output)
        pooled = tf.keras.layers.GlobalMaxPooling1D()(conv)
        conv_layers.append(pooled)

    # Combine CNN outputs
    combined = tf.keras.layers.concatenate(conv_layers)

    # Dropout and fully connected layer
    hidden_1 = tf.keras.layers.Dense(hidden_size, activation='relu', name='hidden_layer_1')(combined)
    hidden_1 = tf.keras.layers.Dropout(dropout)(hidden_1)
    classification = tf.keras.layers.Dense(num_classes, activation='softmax', name='classification_layer')(hidden_1)

    classification_model = tf.keras.Model(inputs=[input_ids, token_type_ids, attention_mask], outputs=[classification])
    classification_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                                 loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
                                 metrics='accuracy')
    return classification_model

# %%
#let's get a fresh instance of the bert_model -- good practice
bert_model = TFBertModel.from_pretrained('bert-base-uncased')
bert_classification_model = create_bert_classification_model(bert_model, num_train_layers=12)

# %%
#confirm all layers are frozen
bert_classification_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  attention_mask_layer (Inpu  [(None, 512)]                0         []
#  tLayer)
#
#  input_ids_layer (InputLaye  [(None, 512)]                0         []
#  r)
#
#  token_type_ids_layer (Inpu  [(None, 512)]                0         []
#  tLayer)
#
#  tf_bert_model_2 (TFBertMod  TFBaseModelOutputWithPooli   1094822   ['attention_mask_layer[0][0]',
#  el)                         ngAndCrossAttentions(last_   40         'input_ids_layer[0][0]',
#                              hidden_state=(None, 512, 7              'token_type_ids_layer[0][0]']
#                              68),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  conv1d_3 (Conv1D)           (None, 510, 100)             230500    ['tf_bert_model_2[0][0]']
#
#  conv1d_4 (Conv1D)           (None, 509, 100)             307300    ['tf_bert_model_2[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 508, 100)             384100    ['tf_bert_model_2[0][0]']
#
#  global_max_pooling1d_3 (Gl  (None, 100)                  0         ['conv1d_3[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_4 (Gl  (None, 100)                  0         ['conv1d_4[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_5 (Gl  (None, 100)                  0         ['conv1d_5[0][0]']
#  obalMaxPooling1D)
#
#  concatenate_1 (Concatenate  (None, 300)                  0         ['global_max_pooling1d_3[0][0]
#  )                                                                  ',
#                                                                      'global_max_pooling1d_4[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_5[0][0]
#                                                                     ']
#
#  hidden_layer_1 (Dense)      (None, 768)                  231168    ['concatenate_1[0][0]']
#
#  dropout_112 (Dropout)       (None, 768)                  0         ['hidden_layer_1[0][0]']
#
#  classification_layer (Dens  (None, 3)                    2307      ['dropout_112[0][0]']
#  e)
#
# ==================================================================================================
# Total params: 110637615 (422.05 MB)
# Trainable params: 110637615 (422.05 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(bert_classification_model, show_shapes=True, dpi=90)

# %%
from tensorflow.keras.callbacks import EarlyStopping
# Early stopping callback to avoid overfitting issue
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=1,
    mode='max',
    restore_best_weights=True  # Restore model weights from the epoch with the best value of the monitored quantity
)

# %%
bert_classification_model_history = bert_classification_model.fit(
    [x_train.input_ids, x_train.token_type_ids, x_train.attention_mask],
    y_train,
    validation_data=([x_validate.input_ids, x_validate.token_type_ids, x_validate.attention_mask], y_validate),
    batch_size=32,
    epochs=5,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/5
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model_2/bert/pooler/dense/kernel:0', 'tf_bert_model_2/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model_2/bert/pooler/dense/kernel:0', 'tf_bert_model_2/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model_2/bert/pooler/dense/kernel:0', 'tf_bert_model_2/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model_2/bert/pooler/dense/kernel:0', 'tf_bert_model_2/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 242/242 [==============================] - 249s 865ms/step - loss: 0.8654 - accuracy: 0.5873 - val_loss: 0.6361 - val_accuracy: 0.7149
# Epoch 2/5
# 242/242 [==============================] - 206s 849ms/step - loss: 0.5572 - accuracy: 0.7707 - val_loss: 0.5338 - val_accuracy: 0.7855
# Epoch 3/5
# 242/242 [==============================] - 205s 849ms/step - loss: 0.4156 - accuracy: 0.8364 - val_loss: 0.4980 - val_accuracy: 0.8145
# Epoch 4/5
# 242/242 [==============================] - 205s 849ms/step - loss: 0.2586 - accuracy: 0.9044 - val_loss: 0.3982 - val_accuracy: 0.8507
# Epoch 5/5
# 242/242 [==============================] - 205s 849ms/step - loss: 0.1749 - accuracy: 0.9382 - val_loss: 0.5263 - val_accuracy: 0.8299

# %%
history = bert_classification_model_history.history

# Plotting accuracy
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history['accuracy'], label='Training Accuracy')
plt.plot(history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plotting loss
plt.subplot(1,2,2)
plt.plot(history['loss'], label='Training Loss')
plt.plot(history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
predictions_model= bert_classification_model.predict([x_test.input_ids, x_test.token_type_ids, x_test.attention_mask])
predictions_model = tf.argmax(predictions_model, axis=-1)
predictions_model
# Out:
# 70/70 [==============================] - 21s 262ms/step
# <tf.Tensor: shape=(2213,), dtype=int64, numpy=array([2, 2, 2, ..., 2, 2, 1])>

# %%
print(classification_report(y_test, predictions_model.numpy(),
                            target_names=['Left ','Center','Right']))
# Out:
#               precision    recall  f1-score   support
#
#        Left        0.81      0.84      0.82       751
#       Center       0.89      0.84      0.86       572
#        Right       0.82      0.83      0.83       890
#
#     accuracy                           0.83      2213
#    macro avg       0.84      0.83      0.84      2213
# weighted avg       0.84      0.83      0.83      2213

# %%
def plot_confusion_matrix(y_true, y_pred, label_names):
    cm = tf.math.confusion_matrix(y_true, y_pred)
    cm = cm/cm.numpy().sum(axis=1)[:, tf.newaxis]

    plt.figure(figsize=(20,7))
    sns.heatmap(
        cm, annot=True,
        xticklabels=label_names,
        yticklabels=label_names)
    plt.xlabel("Predicted")
    plt.ylabel("True")

# %%
target_names=['Left ','Center','Right']
plot_confusion_matrix(y_test, predictions_model.numpy(), target_names)

# %%
bert_cls_wrong_guesses = np.where(y_test != predictions_model.numpy())

# %%
print(f'Number of Wrong Guesses: ',len(bert_cls_wrong_guesses[0]))
# Out:
# Number of Wrong Guesses:  367

# %%
#sampling 20 of the wrong precditions
wrong_guesses = [i for i in np.squeeze(bert_cls_wrong_guesses[0])]
decoded_wrong_guesses_text=[]

for i in wrong_guesses[:]:
  decoded_text = bert_tokenizer.decode(x_test['input_ids'][i], skip_special_tokens=True)

  # print("Input text:")
  # print(decoded_text)
  decoded_wrong_guesses_text.append(decoded_text)
  # print("True label:")
  # print(y_test.iloc[i])
  # print("Predicted label:")
  # print(predictions_model.numpy()[i])

  # print("-" * 50)

# %%
len(decoded_wrong_guesses_text)
# Out:
# 367

# %%
sources_analysis = test_df.loc[wrong_guesses]

# %%
sources_analysis['source']
# Count the occurrences of each source
source_counts = sources_analysis['source'].value_counts()

# Create a bar plot
plt.figure(figsize=(12, 6))
source_counts.plot(kind='bar')

# Customize the plot
plt.title('Distribution of Wrong Guess''Sources')
plt.xlabel('Source')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Convert 'date' to datetime if it's not already
sources_analysis['date'] = pd.to_datetime(sources_analysis['date'])

# Extract year from the date
sources_analysis['year'] = sources_analysis['date'].dt.year

# Count occurrences of each year
year_counts = sources_analysis['year'].value_counts().sort_index()

# Create a bar plot
plt.figure(figsize=(12, 6))
year_counts.plot(kind='bar')

# Customize the plot
plt.title('Distribution of Sources by Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=0)  # No rotation for years
plt.tight_layout()

# Show the plot
plt.show()

# %%
for i in wrong_guesses[:50]:
  decoded_text = bert_tokenizer.decode(x_test['input_ids'][i], skip_special_tokens=True)

# True label:
# 2
# Predicted label:
# 0
# --------------------------------------------------
# Input text:
# the house passed senate budget resolution vote 216212. passing budget resolution allows republican start fast track tax plan. some gop member upset key provision. the house passed senate budget resolution thursday vote 216 212, last procedural step gop move fasttrack taxreform legislation thats expected unveiled next week. every democrat voted bill, along 20 republicans. republican leader succeeded vote despite lastminute handwringing, since republican taxreform framework proposes elimination state local tax deduction. deduction allows people shave pay state local tax federal tax bill. by eliminating salt deduction, republican would offset significant number planned tax cut — saving $ 1. 3 trillion 10 years, according analysis tax policy center. but republican hightax state like california, new york, massachusetts, many people take deduction, expressed lastminute concern elimination deduction. instance, rep. frank lobiondo new jersey tweeted would vote budget. chris krueger, analyst cowen washington research group, said enough member high salt deduction state block budget. there 52 house republican 24seat majority represent district overindex deduction ( california, illinois, new york, new jersey, minnesota, etc. ), krueger wrote thursday. core group ( presumably enough block budget ) threatening withhold vote budget guarantee protect salt. passing senate budget resolution key tax reform measure includes instruction budget reconciliation. reconciliation process allows bill pas senate majority votes. since gop 52seat majority senate, reconciliation key avoiding democratic filibuster. in end, california republicans, handful new york republicans, voted yes. republican celebrated passage budget, including president, applauded win twitter. big news budget passed! trump said. in statement following vote, rep. kevin brady, house way mean committee chair, said vote pave way release full tax bill november 1. today historic day — ready deliver tax relief improves life middleincome american struggling family left behind slowgrowing economy, said statement.
# True label:
# 1
# Predicted label:
# 2
# --------------------------------------------------
# Input text:
# is world becoming better place? human beings, average, becoming healthier, richer, safer? they ’ re not, not? better? each year, bill melinda gate foundation release annual goalkeeper report. publication thick chart graphs, metric statistics. usually, it ’ s optimistic — global poverty, infant mortality, host key measure dashed toward decency recent years, gates sought make sure public know progress made. the 2018 edition, however, started tougher note. optimism requires candid hard problem still need solved, ” gates write. that ’ s year ’ s goalkeeper data report aim do : confront pressing yet neglected challenge, identify promising strategy meet it. ” to put bluntly, ” continue, decade stunning progress fight poverty disease may verge stalling. poorest part world growing faster everywhere else ; baby born place it ’ s hardest lead healthy productive life. ” the gates talking specifically africa. africa whole projected nearly double size 2050, mean even percentage poor people continent cut half, number poor people stay same, ” write. there topic philanthropic world fraught population growth. history effort analyze address filled bad prediction and, worse, cruel solutions. development expert alex ezeh writes elsewhere report, population issue difficult talk development community ignoring years. ” the gateses, though, trying take different approach issue. rather seeing population problem demographic projections, they ’ re framing poverty problem — and, matter, opportunity. there ’ s lot discussion happens large number young people poorest country denied opportunity build better lives, ” write. people worry insecurity, instability, mass migration. wish would also recognize young people ’ s enormous potential drive growth. activists, innovators, leaders, worker future. ” with endowment $ 50 billion, bill melinda gate foundation is, far, largest foundation world. matters, idea power work matter. i spoke bill gate podcast, ezra klein show. discussed geographic political force held africa back ; whether economic development brings political freedom ; risk posed artificial intelligence ; weight future human lives ; whether philanthropist worry animal suffering ; much more. full audio here. transcript conversation, edited length clarity, follows. ezra klein you often make point, experience, pushing optimistic narrative face increasingly pessimistic culture. new goalkeeper report, begin writing, put bluntly, decade stunning progress fight poverty disease may verge stalling. ” that? bill gate well, point dramatic decline 26 percent world ’ s population extreme poverty 9 percent, lot came asian country — first china later india, indonesia, pakistan bangladesh — reasonable job governance. invested health. invested agricultural productivity. improved education
# True label:
# 0
# Predicted label:
# 2
# --------------------------------------------------
# Input text:
